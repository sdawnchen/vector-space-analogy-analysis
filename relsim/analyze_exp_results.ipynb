# %%
# Load the data

import pandas as pd
import numpy as np
all_data = pd.read_csv('relsim_raw_data.csv')
all_data[:10]
# Out:
#    sub_id  trial_idx pair_left_type pair_left_word1 pair_left_word2  \
# 0       1          1             4b            dull          bright
# 1       1          2             4b          chilly            warm
# 2       1          3             2a           jeans          zipper
# 3       1          4             2a            bird        feathers
# 4       1          5             1a       appliance    refrigerator
# 5       1          6             1a          school      university
# 6       1          7             2b           geese          gaggle
# 7       1          8             2b          school            fish
# 8       1          9             3a             old          mature
# 9       1         10             2a            city           block
#
#   pair_right_type pair_right_word1 pair_right_word2    rt  time_elapsed  \
# 0              4b             thin              fat  3155         23271
# 1              4c               go             stay  2613         26900
# 2              2a         building             wall  1353         29258
# 3              2a             foot              toe  1361         31624
# 4              1a           mammal         porpoise  1014         33643
# 5              1a              art         abstract   962         35608
# 6              2a         computer             chip  1834         38446
# 7              2a            jeans           zipper  1941         41392
# 8              3a         restroom         bathroom  1112         43509
# 9              2a            zebra          stripes  1851         46364
#
#    sim_rating attention_check  comparison_type
# 0           4              no   within-subtype
# 1           4              no  between-subtype
# 2           4              no   within-subtype
# 3           4              no   within-subtype
# 4           4              no   within-subtype
# 5           4              no   within-subtype
# 6           4              no  between-subtype
# 7           4              no  between-subtype
# 8           4              no   within-subtype
# 9           4              no   within-subtype

# %%
# Find the "bad" subjects--those who failed too many attention checks

fail_threshold = 2
bad_subs = []
attn_checks = all_data[all_data['attention_check'] == 'yes']
for sub_id in attn_checks['sub_id'].unique():
    sub_data = attn_checks[attn_checks['sub_id'] == sub_id]
    same_words = sub_data['pair_left_word1'] == sub_data['pair_left_word2']
    diff_words = np.logical_not(same_words)
    not_rated_same = sub_data['sim_rating'] != 7
    not_rated_diff = sub_data['sim_rating'] != 1
    num_failed = np.sum(np.logical_or(np.logical_and(same_words, not_rated_same),
                                      np.logical_and(diff_words, not_rated_diff)))
    if num_failed >= fail_threshold:
        bad_subs.append(sub_id)
        
print 'Number of "bad" subjects:', len(bad_subs)
# Out:
# Number of "bad" subjects: 158

# %%
# Get the "good" data

good_rows = reduce(np.logical_and,
                   [all_data['sub_id'] != sub_id for sub_id in bad_subs])
good_data = all_data[good_rows]
good_data = good_data[good_data['attention_check'] == 'no']

print 'Number of "good" subjects:', len(good_data['sub_id'].unique())
# Out:
#  Total number of good subjects: 665

# %%
# Check that the "good" data make sense

all_ratings = good_data['sim_rating']
ws_ratings = good_data[good_data['comparison_type'] == 'within-subtype']['sim_rating']
bs_ratings = good_data[good_data['comparison_type'] == 'between-subtype']['sim_rating']
bt_ratings = good_data[good_data['comparison_type'] == 'between-type']['sim_rating']

print 'All comparisons'
print 'Mean:', all_ratings.mean()
print 'SD:', all_ratings.std()
print

print 'Within-subtype comparisons'
print 'Mean:', ws_ratings.mean()
print 'SD:', ws_ratings.std()
print

print 'Between-subtype comparisons'
print 'Mean:', bs_ratings.mean()
print 'SD:', bs_ratings.std()
print

print 'Between-type comparisons'
print 'Mean:', bt_ratings.mean()
print 'SD:', bt_ratings.std()
print 

print 'Average RT per trial (s):', good_data['rt'].mean() / 1000
# Out:
# All comparisons
# Mean: 4.51628571429
# SD: 2.16540139027
#
# Within-subtype comparisons
# Mean: 5.00589572078
# SD: 1.98065044753
#
# Between-subtype comparisons
# Mean: 4.02379048381
# SD: 2.14477359419
#
# Between-type comparisons
# Mean: 2.69833536338
# SD: 1.92882837905
#
# Average RT per trial: 7.63890157895

# %%
# Get the average rating for each comparison

data_subset = good_data

comp_ratings = {}

for r in xrange(data_subset.shape[0]):
    row = data_subset.iloc[r]
    rel1 = row['pair_left_type']
    rel2 = row['pair_right_type']
    left_word1 = row['pair_left_word1']
    left_word2 = row['pair_left_word2']
    right_word1 = row['pair_right_word1']
    right_word2 = row['pair_right_word2']
    rating = row['sim_rating']

    left_pair = (left_word1, left_word2)
    right_pair = (right_word1, right_word2)

    # Use alphabetical order to get a canonical order for the pairs in this
    # comparison (i.e., left-right presentation order doesn't matter)
    if left_word1 + left_word2 < right_word1 + right_word2:
        comp = (rel1, rel2, left_pair, right_pair)
    else:
        comp = (rel2, rel1, right_pair, left_pair)

    if comp in comp_ratings:
        ratings_sum, count = comp_ratings[comp]
        ratings_sum += rating
        count += 1
        comp_ratings[comp] = (ratings_sum, count)
    else:
        comp_ratings[comp] = (rating, 1)
            
num_comps = len(comp_ratings)
print 'Total # of comparisons:', num_comps

# Calculate average ratings
count_sum = 0
for comp, values in comp_ratings.iteritems():
    ratings_sum, count = values
    avg_rating = ratings_sum / float(count)
    comp_ratings[comp] = (avg_rating, count)
    count_sum += count
    
print 'Avg # of ratings per comparison:', count_sum / float(num_comps)
print

# Sort the comparisons from highest rating to lowest and print them
sorted_comps = sorted(comp_ratings, key=comp_ratings.__getitem__, reverse=True)
for comp in sorted_comps:
    avg_rating, count = comp_ratings[comp]
    print '{}: {} (n = {})'.format(comp, avg_rating, count)
# Out:
# Total # of comparisons: 6194
# Avg # of ratings per comparison: 10.736196319
#
# ('3a', '3a', ('bathroom', 'restroom'), ('restroom', 'bathroom')): 7.0 (n = 10)
# ('1a', '1a', ('animal', 'carabao'), ('animal', 'pig')): 7.0 (n = 10)
# ('7c', '7c', ('doctor', 'stethoscope'), ('hairdresser', 'comb')): 6.91666666667 (n = 12)
# ('7c', '7c', ('chef', 'knife'), ('writer', 'pen')): 6.9 (n = 10)
# ('6a', '4b', ('careful', 'reckless'), ('pretty', 'ugly')): 6.9 (n = 10)
# ('9a', '9a', ('hangar', 'airplane'), ('refrigerator', 'food')): 6.9 (n = 10)
# ('4b', '4b', ('bright', 'dark'), ('easy', 'difficult')): 6.9 (n = 10)
# ('4b', '4b', ('bad', 'good'), ('dirty', 'clean')): 6.9 (n = 10)
# ('9a', '9a', ('bank', 'money'), ('refrigerator', 'food')): 6.9 (n = 10)
# ('4b', '4b', ('big', 'small'), ('good', 'bad')): 6.9 (n = 10)
# ('4b', '4b', ('good', 'bad'), ('tall', 'short')): 6.9 (n = 10)
# ('5a', '5a', ('fire', 'hot'), ('snow', 'cold')): 6.9 (n = 10)
# ('4b', '4b', ('dark', 'light'), ('difficult', 'easy')): 6.83333333333 (n = 12)
# ('7c', '7c', ('chef', 'knife'), ('soldier', 'gun')): 6.83333333333 (n = 12)
# ('4b', '4b', ('hairy', 'bald'), ('ugly', 'pretty')): 6.83333333333 (n = 12)
# ('4b', '4b', ('bright', 'dark'), ('excited', 'bored')): 6.83333333333 (n = 12)
# ('7c', '7c', ('gardener', 'shovel'), ('police', 'gun')): 6.83333333333 (n = 12)
# ('4b', '4b', ('black', 'white'), ('excited', 'bored')): 6.83333333333 (n = 12)
# ('9a', '9a', ('aquarium', 'fish'), ('hive', 'bees')): 6.83333333333 (n = 12)
# ('3a', '3a', ('pants', 'trousers'), ('spectacles', 'glasses')): 6.81818181818 (n = 11)
# ('7c', '7c', ('barber', 'scissors'), ('surgeon', 'scalpel')): 6.81818181818 (n = 11)
# ('4b', '4b', ('bald', 'hairy'), ('dark', 'light')): 6.8 (n = 10)
# ('7c', '7c', ('drummer', 'sticks'), ('soldier', 'gun')): 6.8 (n = 10)
# ('1a', '1a', ('appliance', 'refrigerator'), ('clothing', 'shirt')): 6.8 (n = 10)
# ('3a', '3a', ('clean', 'tidy'), ('pretty', 'beautiful')): 6.8 (n = 10)
# ('5a', '5a', ('pillow', 'soft'), ('steel', 'tough')): 6.8 (n = 10)
# ('4b', '4b', ('excited', 'bored'), ('smart', 'stupid')): 6.8 (n = 10)
# ('1a', '1a', ('couch', 'furniture'), ('dollar', 'currency')): 6.8 (n = 10)
# ('4b', '4b', ('dirty', 'clean'), ('pretty', 'ugly')): 6.8 (n = 10)
# ('3a', '3a', ('beautiful', 'pretty'), ('cute', 'adorable')): 6.8 (n = 10)
# ('1e', '1a', ('car', 'Honda'), ('dog', 'chihuahua')): 6.8 (n = 10)
# ('7c', '7c', ('musician', 'instrument'), ('soldier', 'gun')): 6.8 (n = 10)
# ('7c', '7c', ('chemist', 'beaker'), ('housekeeper', 'broom')): 6.8 (n = 10)
# ('4b', '4b', ('dirty', 'clean'), ('tough', 'weak')): 6.8 (n = 10)
# ('9a', '9a', ('aquarium', 'fish'), ('zoo', 'animals')): 6.8 (n = 10)
# ('3a', '3a', ('house', 'dwelling'), ('option', 'choice')): 6.8 (n = 10)
# ('4b', '4b', ('big', 'small'), ('hot', 'cold')): 6.8 (n = 10)
# ('1a', '1a', ('appliance', 'refrigerator'), ('automobile', 'van')): 6.8 (n = 10)
# ('9a', '9a', ('aquarium', 'fish'), ('garden', 'flower')): 6.8 (n = 10)
# ('2a', '2a', ('bird', 'wings'), ('fish', 'fin')): 6.8 (n = 10)
# ('1a', '1a', ('couch', 'furniture'), ('oak', 'tree')): 6.8 (n = 10)
# ('7c', '7c', ('soldier', 'gun'), ('writer', 'pen')): 6.8 (n = 10)
# ('9a', '9a', ('library', 'books'), ('supermarket', 'groceries')): 6.8 (n = 10)
# ('7c', '7c', ('musician', 'instrument'), ('runner', 'sneakers')): 6.8 (n = 10)
# ('3a', '3a', ('beautiful', 'pretty'), ('pretty', 'beautiful')): 6.8 (n = 10)
# ('3a', '3a', ('beautiful', 'pretty'), ('clean', 'tidy')): 6.8 (n = 10)
# ('9a', '9a', ('school', 'children'), ('zoo', 'animals')): 6.8 (n = 10)
# ('9a', '9a', ('bank', 'money'), ('library', 'books')): 6.8 (n = 10)
# ('7c', '7c', ('barber', 'scissors'), ('maid', 'broom')): 6.8 (n = 10)
# ('7c', '7c', ('chef', 'knife'), ('fairy', 'wand')): 6.8 (n = 10)
# ('7c', '7c', ('hairdresser', 'comb'), ('maid', 'broom')): 6.78571428571 (n = 14)
# ('7c', '7c', ('chemist', 'beaker'), ('doctor', 'stethoscope')): 6.78571428571 (n = 14)
# ('10a', '10a', ('cross', 'christianity'), ('crown', 'royalty')): 6.78571428571 (n = 14)
# ('9a', '9a', ('dresser', 'clothes'), ('library', 'books')): 6.75 (n = 12)
# ('7c', '7c', ('gardener', 'trowel'), ('surgeon', 'scalpel')): 6.75 (n = 12)
# ('2a', '2a', ('bird', 'feathers'), ('cat', 'whiskers')): 6.72727272727 (n = 11)
# ('9a', '9a', ('bank', 'money'), ('supermarket', 'groceries')): 6.72727272727 (n = 11)
# ('1a', '1a', ('automobile', 'van'), ('furniture', 'couch')): 6.72727272727 (n = 11)
# ('7c', '7c', ('barber', 'scissors'), ('chef', 'knife')): 6.72727272727 (n = 11)
# ('2a', '2a', ('bird', 'feathers'), ('fish', 'fin')): 6.72727272727 (n = 11)
# ('4b', '4b', ('hairy', 'bald'), ('smart', 'stupid')): 6.7 (n = 10)
# ('3a', '3a', ('beautiful', 'pretty'), ('tedious', 'monotonous')): 6.7 (n = 10)
# ('4b', '4b', ('beautiful', 'hideous'), ('fast', 'slow')): 6.7 (n = 10)
# ('7c', '7c', ('drummer', 'sticks'), ('writer', 'pen')): 6.7 (n = 10)
# ('7c', '7c', ('doctor', 'thermometer'), ('gardener', 'trowel')): 6.7 (n = 10)
# ('7c', '7c', ('gardener', 'trowel'), ('writer', 'pen')): 6.7 (n = 10)
# ('7c', '7c', ('doctor', 'stethoscope'), ('writer', 'pen')): 6.7 (n = 10)
# ('7c', '7c', ('doctor', 'thermometer'), ('hairdresser', 'comb')): 6.7 (n = 10)
# ('3a', '3a', ('clean', 'tidy'), ('kid', 'child')): 6.7 (n = 10)
# ('3a', '3a', ('spectacles', 'glasses'), ('spin', 'twirl')): 6.7 (n = 10)
# ('1a', '1a', ('clothing', 'shirt'), ('furniture', 'couch')): 6.7 (n = 10)
# ('9a', '9a', ('bus', 'passengers'), ('school', 'children')): 6.7 (n = 10)
# ('8b', '8a', ('embarrassed', 'blush'), ('sadness', 'tears')): 6.7 (n = 10)
# ('9a', '9a', ('cupboard', 'dishes'), ('library', 'books')): 6.7 (n = 10)
# ('9a', '9a', ('hangar', 'airplane'), ('library', 'books')): 6.7 (n = 10)
# ('7c', '7c', ('driver', 'car'), ('maid', 'broom')): 6.7 (n = 10)
# ('7c', '7c', ('driver', 'car'), ('shooter', 'gun')): 6.7 (n = 10)
# ('1a', '1a', ('dog', 'chihuahua'), ('dog', 'poodle')): 6.7 (n = 10)
# ('2a', '2b', ('bouquet', 'flower'), ('pride', 'lion')): 6.7 (n = 10)
# ('4b', '4b', ('dull', 'bright'), ('thin', 'fat')): 6.7 (n = 10)
# ('9a', '9a', ('bank', 'money'), ('closet', 'clothes')): 6.7 (n = 10)
# ('9a', '9a', ('bank', 'money'), ('bathroom', 'toilet')): 6.7 (n = 10)
# ('1a', '1a', ('clothing', 'shirt'), ('politician', 'senator')): 6.7 (n = 10)
# ('9a', '9a', ('forest', 'trees'), ('garden', 'flower')): 6.7 (n = 10)
# ('1a', '1a', ('bird', 'swan'), ('color', 'red')): 6.7 (n = 10)
# ('5a', '5a', ('priest', 'holy'), ('professor', 'intellectual')): 6.7 (n = 10)
# ('7c', '7c', ('maid', 'broom'), ('surgeon', 'scalpel')): 6.7 (n = 10)
# ('9a', '9a', ('fridge', 'food'), ('supermarket', 'groceries')): 6.7 (n = 10)
# ('4b', '4b', ('chilly', 'warm'), ('dark', 'light')): 6.7 (n = 10)
# ('9a', '9a', ('closet', 'clothes'), ('fridge', 'food')): 6.7 (n = 10)
# ('3a', '3a', ('raise', 'elevate'), ('spin', 'twirl')): 6.7 (n = 10)
# ('9a', '9a', ('classroom', 'students'), ('forest', 'trees')): 6.7 (n = 10)
# ('9a', '9a', ('aquarium', 'fish'), ('closet', 'clothes')): 6.7 (n = 10)
# ('7c', '7c', ('barber', 'scissors'), ('policeman', 'handcuffs')): 6.7 (n = 10)
# ('1a', '1a', ('car', 'mustang'), ('school', 'university')): 6.7 (n = 10)
# ('7c', '7c', ('policeman', 'handcuffs'), ('teacher', 'chalk')): 6.7 (n = 10)
# ('7c', '7c', ('chef', 'knife'), ('housekeeper', 'broom')): 6.7 (n = 10)
# ('2a', '2a', ('dog', 'tail'), ('fish', 'fin')): 6.66666666667 (n = 12)
# ('1e', '1a', ('car', 'Camaro'), ('dog', 'poodle')): 6.66666666667 (n = 12)
# ('2a', '2a', ('foot', 'toe'), ('hand', 'finger')): 6.66666666667 (n = 12)
# ('4b', '4b', ('easy', 'difficult'), ('hairy', 'bald')): 6.66666666667 (n = 12)
# ('2a', '2a', ('cat', 'whiskers'), ('fish', 'fin')): 6.66666666667 (n = 12)
# ('3a', '3a', ('beautiful', 'pretty'), ('pants', 'trousers')): 6.64705882353 (n = 17)
# ('7c', '7c', ('doctor', 'stethoscope'), ('soldier', 'gun')): 6.63636363636 (n = 11)
# ('5a', '5a', ('fire', 'hot'), ('steel', 'strong')): 6.63636363636 (n = 11)
# ('7c', '7c', ('chef', 'knife'), ('hairdresser', 'comb')): 6.63636363636 (n = 11)
# ('1a', '1a', ('insect', 'ant'), ('weapon', 'spear')): 6.63636363636 (n = 11)
# ('7c', '7c', ('drummer', 'sticks'), ('maid', 'broom')): 6.63636363636 (n = 11)
# ('7c', '7c', ('hairdresser', 'comb'), ('housekeeper', 'broom')): 6.63636363636 (n = 11)
# ('1a', '1a', ('appliance', 'refrigerator'), ('insect', 'ant')): 6.61538461538 (n = 13)
# ('1a', '1a', ('insect', 'ant'), ('rodent', 'mouse')): 6.6 (n = 10)
# ('9a', '9a', ('classroom', 'students'), ('zoo', 'animals')): 6.6 (n = 10)
# ('7c', '7c', ('barber', 'scissors'), ('gardener', 'shovel')): 6.6 (n = 10)
# ('1a', '1a', ('appliance', 'refrigerator'), ('bird', 'swan')): 6.6 (n = 10)
# ('9a', '9a', ('bus', 'passengers'), ('refrigerator', 'food')): 6.6 (n = 10)
# ('1a', '1a', ('mammal', 'porpoise'), ('rodent', 'mouse')): 6.6 (n = 10)
# ('7c', '7c', ('gardener', 'trowel'), ('maid', 'broom')): 6.6 (n = 10)
# ('7c', '7c', ('doctor', 'stethoscope'), ('policeman', 'handcuffs')): 6.6 (n = 10)
# ('3a', '3a', ('bathroom', 'restroom'), ('boat', 'ship')): 6.6 (n = 10)
# ('3a', '3a', ('bathroom', 'restroom'), ('pants', 'trousers')): 6.6 (n = 10)
# ('9a', '9a', ('kitchen', 'food'), ('zoo', 'animals')): 6.6 (n = 10)
# ('9a', '9a', ('bank', 'money'), ('hive', 'bees')): 6.6 (n = 10)
# ('7c', '7c', ('housekeeper', 'broom'), ('teacher', 'chalk')): 6.6 (n = 10)
# ('7c', '7c', ('gardener', 'shovel'), ('gardener', 'trowel')): 6.6 (n = 10)
# ('7c', '7c', ('gardener', 'trowel'), ('musician', 'instrument')): 6.6 (n = 10)
# ('7c', '7c', ('musician', 'instrument'), ('surgeon', 'scalpel')): 6.6 (n = 10)
# ('7c', '7c', ('hairdresser', 'comb'), ('musician', 'instrument')): 6.6 (n = 10)
# ('7c', '7c', ('gardener', 'shovel'), ('surgeon', 'scalpel')): 6.6 (n = 10)
# ('8a', '8a', ('boredom', 'repetition'), ('repetition', 'boredom')): 6.6 (n = 10)
# ('5a', '5a', ('clay', 'malleable'), ('steel', 'strong')): 6.6 (n = 10)
# ('7c', '7c', ('drummer', 'sticks'), ('runner', 'sneakers')): 6.6 (n = 10)
# ('9a', '9a', ('kitchen', 'food'), ('library', 'books')): 6.6 (n = 10)
# ('1a', '1a', ('dog', 'poodle'), ('insect', 'ant')): 6.6 (n = 10)
# ('10a', '10a', ('badge', 'authority'), ('crown', 'royalty')): 6.6 (n = 10)
# ('7c', '7c', ('chemist', 'beaker'), ('gardener', 'shovel')): 6.6 (n = 10)
# ('9a', '9a', ('cupboard', 'dishes'), ('dresser', 'clothes')): 6.6 (n = 10)
# ('7c', '7c', ('doctor', 'stethoscope'), ('gardener', 'shovel')): 6.6 (n = 10)
# ('7c', '7c', ('chef', 'knife'), ('maid', 'broom')): 6.6 (n = 10)
# ('7c', '7c', ('doctor', 'stethoscope'), ('musician', 'instrument')): 6.6 (n = 10)
# ('4b', '4b', ('good', 'bad'), ('hairy', 'bald')): 6.6 (n = 10)
# ('2a', '2a', ('city', 'block'), ('play', 'act')): 6.6 (n = 10)
# ('7c', '7c', ('shooter', 'gun'), ('surgeon', 'scalpel')): 6.6 (n = 10)
# ('1a', '1a', ('appliance', 'refrigerator'), ('furniture', 'couch')): 6.6 (n = 10)
# ('9a', '2a', ('aquarium', 'fish'), ('freezer', 'ice')): 6.6 (n = 10)
# ('1a', '1a', ('car', 'mustang'), ('dog', 'chihuahua')): 6.6 (n = 10)
# ('3a', '3a', ('bathroom', 'restroom'), ('option', 'choice')): 6.6 (n = 10)
# ('7c', '7c', ('hairdresser', 'comb'), ('policeman', 'handcuffs')): 6.6 (n = 10)
# ('9a', '9a', ('forest', 'trees'), ('library', 'books')): 6.6 (n = 10)
# ('1a', '1a', ('furniture', 'couch'), ('pet', 'dog')): 6.6 (n = 10)
# ('4b', '4b', ('beautiful', 'hideous'), ('hairy', 'bald')): 6.6 (n = 10)
# ('9a', '9a', ('hangar', 'airplane'), ('school', 'children')): 6.6 (n = 10)
# ('3a', '3a', ('house', 'abode'), ('kid', 'child')): 6.6 (n = 10)
# ('3a', '3a', ('beautiful', 'pretty'), ('option', 'choice')): 6.6 (n = 10)
# ('9a', '9a', ('classroom', 'students'), ('store', 'shopper')): 6.6 (n = 10)
# ('7c', '7c', ('barber', 'scissors'), ('teacher', 'chalk')): 6.6 (n = 10)
# ('9a', '9a', ('garden', 'flower'), ('library', 'books')): 6.6 (n = 10)
# ('7c', '7c', ('policeman', 'handcuffs'), ('surgeon', 'scalpel')): 6.6 (n = 10)
# ('1a', '1a', ('politician', 'senator'), ('weapon', 'spear')): 6.6 (n = 10)
# ('3a', '3a', ('bathroom', 'restroom'), ('spin', 'twirl')): 6.6 (n = 10)
# ('8a', '8a', ('injury', 'pain'), ('sadness', 'tears')): 6.6 (n = 10)
# ('7c', '7c', ('chemist', 'beaker'), ('policeman', 'handcuffs')): 6.6 (n = 10)
# ('3a', '3a', ('option', 'choice'), ('pants', 'trousers')): 6.6 (n = 10)
# ('4b', '4c', ('chilly', 'warm'), ('go', 'stay')): 6.6 (n = 10)
# ('1a', '1a', ('automobile', 'van'), ('bird', 'swan')): 6.6 (n = 10)
# ('9a', '9a', ('aquarium', 'fish'), ('bank', 'money')): 6.6 (n = 10)
# ('1a', '1e', ('color', 'red'), ('country', 'Ireland')): 6.58823529412 (n = 17)
# ('3a', '3a', ('bathroom', 'restroom'), ('tedious', 'monotonous')): 6.58823529412 (n = 17)
# ('10a', '10a', ('flashing', 'caution'), ('green', 'go')): 6.58333333333 (n = 12)
# ('7c', '7c', ('chef', 'knife'), ('gardener', 'trowel')): 6.58333333333 (n = 12)
# ('9a', '9a', ('garden', 'flower'), ('space', 'planets')): 6.58333333333 (n = 12)
# ('3a', '3a', ('careful', 'cautious'), ('clean', 'tidy')): 6.58333333333 (n = 12)
# ('7c', '7c', ('doctor', 'thermometer'), ('teacher', 'chalk')): 6.58333333333 (n = 12)
# ('1a', '1a', ('dog', 'chihuahua'), ('rodent', 'mouse')): 6.58333333333 (n = 12)
# ('7c', '7c', ('musician', 'instrument'), ('shooter', 'gun')): 6.58333333333 (n = 12)
# ('5a', '5a', ('blanket', 'soft'), ('steel', 'tough')): 6.58333333333 (n = 12)
# ('9a', '9a', ('aquarium', 'fish'), ('library', 'books')): 6.58333333333 (n = 12)
# ('2a', '2a', ('movie', 'scene'), ('play', 'act')): 6.58333333333 (n = 12)
# ('3a', '3a', ('careful', 'cautious'), ('pretty', 'beautiful')): 6.58333333333 (n = 12)
# ('3a', '3a', ('restroom', 'bathroom'), ('spectacles', 'glasses')): 6.58333333333 (n = 12)
# ('7c', '7c', ('maid', 'broom'), ('police', 'gun')): 6.57142857143 (n = 14)
# ('8a', '8a', ('run', 'sweat'), ('workout', 'sweat')): 6.57142857143 (n = 14)
# ('8a', '8a', ('eating', 'fullness'), ('showering', 'cleanliness')): 6.57142857143 (n = 14)
# ('3a', '3a', ('careful', 'cautious'), ('raise', 'elevate')): 6.54545454545 (n = 11)
# ('9a', '9a', ('hive', 'bees'), ('school', 'student')): 6.54545454545 (n = 11)
# ('9a', '9a', ('school', 'student'), ('zoo', 'animals')): 6.54545454545 (n = 11)
# ('3a', '3a', ('bathroom', 'restroom'), ('kid', 'child')): 6.54545454545 (n = 11)
# ('1a', '1a', ('bird', 'swan'), ('dog', 'poodle')): 6.54545454545 (n = 11)
# ('9a', '9a', ('refrigerator', 'food'), ('supermarket', 'groceries')): 6.54545454545 (n = 11)
# ('7c', '7c', ('barber', 'scissors'), ('musician', 'instrument')): 6.53846153846 (n = 13)
# ('1a', '1a', ('rodent', 'mouse'), ('weapon', 'spear')): 6.53846153846 (n = 13)
# ('9a', '9a', ('hive', 'bees'), ('school', 'children')): 6.53846153846 (n = 13)
# ('3a', '3a', ('seat', 'chair'), ('spin', 'twirl')): 6.52941176471 (n = 17)
# ('9a', '9a', ('bus', 'passengers'), ('hive', 'bees')): 6.5 (n = 14)
# ('9a', '9a', ('library', 'books'), ('refrigerator', 'food')): 6.5 (n = 12)
# ('1a', '1a', ('animal', 'carabao'), ('dog', 'chihuahua')): 6.5 (n = 12)
# ('7c', '7c', ('doctor', 'thermometer'), ('fairy', 'wand')): 6.5 (n = 12)
# ('9a', '9a', ('aquarium', 'fish'), ('hangar', 'airplane')): 6.5 (n = 12)
# ('4b', '4b', ('bored', 'excited'), ('hairy', 'bald')): 6.5 (n = 12)
# ('3a', '3a', ('pants', 'trousers'), ('restroom', 'bathroom')): 6.5 (n = 12)
# ('3b', '3a', ('happiness', 'joy'), ('option', 'choice')): 6.5 (n = 12)
# ('9a', '9a', ('hive', 'bees'), ('library', 'books')): 6.5 (n = 12)
# ('5a', '5a', ('fire', 'hot'), ('light', 'bright')): 6.5 (n = 12)
# ('1a', '1a', ('pet', 'dog'), ('weapon', 'spear')): 6.5 (n = 10)
# ('7c', '7c', ('doctor', 'thermometer'), ('police', 'gun')): 6.5 (n = 10)
# ('7c', '7c', ('gardener', 'shovel'), ('policeman', 'handcuffs')): 6.5 (n = 10)
# ('8a', '8a', ('eating', 'fullness'), ('exercise', 'fatigue')): 6.5 (n = 10)
# ('7c', '7c', ('police', 'gun'), ('teacher', 'chalk')): 6.5 (n = 10)
# ('5a', '5a', ('car', 'fast'), ('steel', 'strong')): 6.5 (n = 10)
# ('9a', '9a', ('bank', 'money'), ('forest', 'trees')): 6.5 (n = 10)
# ('3a', '3a', ('house', 'abode'), ('spectacles', 'glasses')): 6.5 (n = 10)
# ('7c', '7c', ('chef', 'knife'), ('shooter', 'gun')): 6.5 (n = 10)
# ('7c', '7c', ('gardener', 'shovel'), ('shopper', 'cart')): 6.5 (n = 10)
# ('3a', '3a', ('pretty', 'beautiful'), ('spin', 'twirl')): 6.5 (n = 10)
# ('7c', '7c', ('barber', 'scissors'), ('hairdresser', 'comb')): 6.5 (n = 10)
# ('1a', '1a', ('insect', 'ant'), ('mammal', 'porpoise')): 6.5 (n = 10)
# ('1a', '1a', ('animal', 'carabao'), ('automobile', 'van')): 6.5 (n = 10)
# ('7c', '7c', ('drummer', 'sticks'), ('surgeon', 'scalpel')): 6.5 (n = 10)
# ('9a', '9a', ('dresser', 'clothes'), ('refrigerator', 'food')): 6.5 (n = 10)
# ('7c', '7c', ('doctor', 'stethoscope'), ('gardener', 'trowel')): 6.5 (n = 10)
# ('7c', '7c', ('hairdresser', 'comb'), ('surgeon', 'scalpel')): 6.5 (n = 10)
# ('7c', '7c', ('gardener', 'shovel'), ('soldier', 'gun')): 6.5 (n = 10)
# ('7c', '7c', ('housekeeper', 'broom'), ('soldier', 'gun')): 6.5 (n = 10)
# ('9a', '9a', ('aquarium', 'fish'), ('school', 'children')): 6.5 (n = 10)
# ('2a', '2a', ('bicycle', 'wheel'), ('foot', 'toe')): 6.5 (n = 10)
# ('3a', '3a', ('option', 'choice'), ('spin', 'twirl')): 6.5 (n = 10)
# ('8a', '8a', ('germs', 'sickness'), ('sex', 'pregnancy')): 6.5 (n = 10)
# ('7c', '7c', ('shopper', 'cart'), ('soldier', 'gun')): 6.5 (n = 10)
# ('3a', '3a', ('house', 'abode'), ('restroom', 'bathroom')): 6.5 (n = 10)
# ('9a', '9a', ('closet', 'clothes'), ('refrigerator', 'food')): 6.5 (n = 10)
# ('1a', '1a', ('animal', 'pig'), ('car', 'mustang')): 6.5 (n = 10)
# ('7c', '7c', ('surgeon', 'scalpel'), ('writer', 'pen')): 6.5 (n = 10)
# ('7c', '7c', ('chemist', 'beaker'), ('hairdresser', 'comb')): 6.5 (n = 10)
# ('7c', '7c', ('gardener', 'shovel'), ('maid', 'broom')): 6.5 (n = 10)
# ('3a', '3a', ('beautiful', 'pretty'), ('careful', 'cautious')): 6.5 (n = 10)
# ('7c', '7c', ('drummer', 'sticks'), ('teacher', 'chalk')): 6.5 (n = 10)
# ('7c', '7c', ('drummer', 'sticks'), ('housekeeper', 'broom')): 6.5 (n = 10)
# ('2a', '2a', ('dance', 'step'), ('movie', 'scene')): 6.5 (n = 10)
# ('9a', '9a', ('fridge', 'food'), ('zoo', 'animals')): 6.5 (n = 10)
# ('7c', '7c', ('chemist', 'beaker'), ('soldier', 'gun')): 6.5 (n = 10)
# ('7c', '7c', ('fairy', 'wand'), ('gardener', 'shovel')): 6.5 (n = 10)
# ('7c', '7c', ('chemist', 'beaker'), ('writer', 'pen')): 6.5 (n = 10)
# ('7c', '7c', ('chef', 'knife'), ('doctor', 'thermometer')): 6.5 (n = 10)
# ('10a', '10a', ('cry', 'help'), ('help', 'cry')): 6.5 (n = 10)
# ('5a', '5a', ('candy', 'sweet'), ('snow', 'cold')): 6.5 (n = 10)
# ('7c', '7c', ('barber', 'scissors'), ('shooter', 'gun')): 6.5 (n = 10)
# ('10a', '10a', ('smoke', 'fire'), ('thunder', 'lightning')): 6.5 (n = 10)
# ('3a', '3a', ('raise', 'elevate'), ('restroom', 'bathroom')): 6.5 (n = 10)
# ('7c', '7c', ('fairy', 'wand'), ('soldier', 'gun')): 6.5 (n = 10)
# ('5a', '5a', ('steel', 'strong'), ('steel', 'tough')): 6.5 (n = 10)
# ('7c', '7c', ('doctor', 'stethoscope'), ('maid', 'broom')): 6.5 (n = 10)
# ('1a', '1a', ('color', 'red'), ('insect', 'ant')): 6.5 (n = 10)
# ('7c', '7c', ('fairy', 'wand'), ('police', 'gun')): 6.5 (n = 10)
# ('8a', '8a', ('explosion', 'damage'), ('injury', 'pain')): 6.5 (n = 10)
# ('1a', '1a', ('automobile', 'van'), ('pen', 'ballpoint')): 6.5 (n = 10)
# ('9a', '9a', ('bank', 'money'), ('kitchen', 'food')): 6.5 (n = 10)
# ('1a', '1a', ('bird', 'swan'), ('insect', 'ant')): 6.5 (n = 10)
# ('3a', '3a', ('pants', 'trousers'), ('sleep', 'doze')): 6.47058823529 (n = 17)
# ('1a', '1a', ('car', 'mustang'), ('furniture', 'couch')): 6.46153846154 (n = 13)
# ('7c', '7c', ('gardener', 'trowel'), ('housekeeper', 'broom')): 6.46153846154 (n = 13)
# ('7c', '7c', ('drummer', 'sticks'), ('hairdresser', 'comb')): 6.46153846154 (n = 13)
# ('7c', '7c', ('chef', 'knife'), ('surgeon', 'scalpel')): 6.46153846154 (n = 13)
# ('7c', '7c', ('barber', 'scissors'), ('writer', 'pen')): 6.46153846154 (n = 13)
# ('7c', '7c', ('musician', 'instrument'), ('writer', 'pen')): 6.46153846154 (n = 13)
# ('3b', '3a', ('giggle', 'laugh'), ('spin', 'twirl')): 6.46153846154 (n = 13)
# ('9a', '9a', ('cupboard', 'dishes'), ('fridge', 'food')): 6.45454545455 (n = 11)
# ('9a', '9a', ('aquarium', 'fish'), ('fridge', 'food')): 6.45454545455 (n = 11)
# ('7c', '7c', ('hairdresser', 'comb'), ('soldier', 'gun')): 6.45454545455 (n = 11)
# ('7c', '7c', ('chef', 'knife'), ('teacher', 'chalk')): 6.45454545455 (n = 11)
# ('3a', '3a', ('careful', 'cautious'), ('option', 'choice')): 6.45454545455 (n = 11)
# ('3a', '3a', ('bathroom', 'restroom'), ('house', 'abode')): 6.45454545455 (n = 11)
# ('9a', '9a', ('hive', 'bees'), ('zoo', 'animals')): 6.45454545455 (n = 11)
# ('1a', '1a', ('dog', 'chihuahua'), ('weapon', 'spear')): 6.45454545455 (n = 11)
# ('9a', '9a', ('bus', 'passengers'), ('zoo', 'animals')): 6.45454545455 (n = 11)
# ('1a', '1a', ('bird', 'swan'), ('weather', 'rain')): 6.45454545455 (n = 11)
# ('1a', '1a', ('appliance', 'refrigerator'), ('dog', 'poodle')): 6.45454545455 (n = 11)
# ('3a', '3b', ('beautiful', 'pretty'), ('shriek', 'scream')): 6.45454545455 (n = 11)
# ('7c', '7c', ('soldier', 'gun'), ('surgeon', 'scalpel')): 6.45454545455 (n = 11)
# ('7c', '7c', ('chef', 'knife'), ('chemist', 'beaker')): 6.45454545455 (n = 11)
# ('9a', '9a', ('refrigerator', 'food'), ('zoo', 'animals')): 6.45454545455 (n = 11)
# ('7c', '7c', ('barber', 'scissors'), ('doctor', 'stethoscope')): 6.45454545455 (n = 11)
# ('9a', '9a', ('aquarium', 'fish'), ('space', 'planets')): 6.42857142857 (n = 14)
# ('4b', '4b', ('big', 'small'), ('dark', 'light')): 6.41666666667 (n = 12)
# ('7c', '7c', ('hairdresser', 'comb'), ('writer', 'pen')): 6.41666666667 (n = 12)
# ('4b', '4b', ('fat', 'thin'), ('hot', 'cold')): 6.41666666667 (n = 12)
# ('7c', '7c', ('maid', 'broom'), ('soldier', 'gun')): 6.41666666667 (n = 12)
# ('4b', '4b', ('dark', 'light'), ('thin', 'fat')): 6.41666666667 (n = 12)
# ('1a', '1a', ('automobile', 'van'), ('dog', 'chihuahua')): 6.41666666667 (n = 12)
# ('4b', '4b', ('bad', 'good'), ('big', 'small')): 6.41666666667 (n = 12)
# ('1a', '1a', ('bird', 'swan'), ('weapon', 'spear')): 6.41666666667 (n = 12)
# ('1a', '1a', ('appliance', 'refrigerator'), ('pet', 'dog')): 6.41666666667 (n = 12)
# ('7c', '7c', ('maid', 'broom'), ('pitcher', 'baseball')): 6.41666666667 (n = 12)
# ('3a', '3a', ('candy', 'sweets'), ('pants', 'trousers')): 6.41176470588 (n = 17)
# ('9a', '9a', ('forest', 'trees'), ('kitchen', 'food')): 6.4 (n = 10)
# ('3a', '3a', ('run', 'sprint'), ('tedious', 'monotonous')): 6.4 (n = 10)
# ('9a', '9a', ('bank', 'money'), ('space', 'planets')): 6.4 (n = 10)
# ('1a', '1a', ('car', 'mustang'), ('weather', 'rain')): 6.4 (n = 10)
# ('1a', '1a', ('dog', 'poodle'), ('school', 'university')): 6.4 (n = 10)
# ('7c', '7c', ('maid', 'broom'), ('shooter', 'gun')): 6.4 (n = 10)
# ('9a', '9a', ('carton', 'milk'), ('hive', 'bees')): 6.4 (n = 10)
# ('7c', '7c', ('chef', 'knife'), ('doctor', 'stethoscope')): 6.4 (n = 10)
# ('5a', '5a', ('blanket', 'soft'), ('fire', 'hot')): 6.4 (n = 10)
# ('8a', '8a', ('loss', 'grief'), ('sadness', 'tears')): 6.4 (n = 10)
# ('2a', '2a', ('bicycle', 'wheel'), ('bird', 'wings')): 6.4 (n = 10)
# ('9a', '9a', ('clothes', 'dresser'), ('library', 'books')): 6.4 (n = 10)
# ('7c', '7c', ('gardener', 'trowel'), ('shooter', 'gun')): 6.4 (n = 10)
# ('1a', '1a', ('animal', 'carabao'), ('clothing', 'shirt')): 6.4 (n = 10)
# ('9a', '9a', ('dresser', 'clothes'), ('hangar', 'airplane')): 6.4 (n = 10)
# ('7c', '7c', ('chef', 'knife'), ('pitcher', 'baseball')): 6.4 (n = 10)
# ('9a', '9a', ('aquarium', 'fish'), ('bus', 'passengers')): 6.4 (n = 10)
# ('9a', '9a', ('closet', 'clothes'), ('hangar', 'airplane')): 6.4 (n = 10)
# ('7c', '7c', ('pitcher', 'baseball'), ('writer', 'pen')): 6.4 (n = 10)
# ('9a', '9a', ('aquarium', 'fish'), ('forest', 'trees')): 6.4 (n = 10)
# ('7c', '7c', ('barber', 'scissors'), ('police', 'gun')): 6.4 (n = 10)
# ('7c', '7c', ('fairy', 'wand'), ('writer', 'pen')): 6.4 (n = 10)
# ('9a', '9a', ('closet', 'clothes'), ('kitchen', 'food')): 6.4 (n = 10)
# ('9a', '9a', ('bathroom', 'toilet'), ('library', 'books')): 6.4 (n = 10)
# ('4b', '4b', ('easy', 'difficult'), ('pretty', 'ugly')): 6.4 (n = 10)
# ('9a', '9a', ('hive', 'bees'), ('store', 'shopper')): 6.4 (n = 10)
# ('1a', '1a', ('color', 'red'), ('mammal', 'porpoise')): 6.4 (n = 10)
# ('9a', '9a', ('bank', 'money'), ('dresser', 'clothes')): 6.4 (n = 10)
# ('9a', '9a', ('library', 'books'), ('zoo', 'animals')): 6.4 (n = 10)
# ('1a', '1a', ('furniture', 'couch'), ('weapon', 'spear')): 6.4 (n = 10)
# ('7c', '7c', ('chemist', 'beaker'), ('surgeon', 'scalpel')): 6.4 (n = 10)
# ('7c', '7c', ('gardener', 'shovel'), ('writer', 'pen')): 6.4 (n = 10)
# ('9a', '9a', ('classroom', 'students'), ('library', 'books')): 6.4 (n = 10)
# ('1a', '1a', ('animal', 'carabao'), ('insect', 'ant')): 6.4 (n = 10)
# ('1a', '1a', ('mammal', 'porpoise'), ('pen', 'ballpoint')): 6.4 (n = 10)
# ('7c', '7c', ('doctor', 'stethoscope'), ('drummer', 'sticks')): 6.4 (n = 10)
# ('5a', '5a', ('dog', 'furry'), ('pizza', 'cheesy')): 6.4 (n = 10)
# ('4b', '4b', ('bad', 'good'), ('dark', 'light')): 6.4 (n = 10)
# ('3a', '3a', ('pants', 'trousers'), ('seat', 'chair')): 6.4 (n = 10)
# ('9a', '9a', ('supermarket', 'groceries'), ('zoo', 'animals')): 6.4 (n = 10)
# ('3a', '3a', ('option', 'choice'), ('raise', 'elevate')): 6.4 (n = 10)
# ('1a', '1a', ('car', 'mustang'), ('dog', 'poodle')): 6.4 (n = 10)
# ('7c', '7c', ('musician', 'instrument'), ('policeman', 'handcuffs')): 6.4 (n = 10)
# ('1a', '1e', ('car', 'mustang'), ('ocean', 'Pacific')): 6.4 (n = 10)
# ('7c', '7c', ('doctor', 'thermometer'), ('policeman', 'handcuffs')): 6.4 (n = 10)
# ('7c', '7c', ('barber', 'scissors'), ('chemist', 'beaker')): 6.4 (n = 10)
# ('7c', '7c', ('lawyer', 'books'), ('runner', 'sneakers')): 6.4 (n = 10)
# ('7c', '7c', ('housekeeper', 'broom'), ('lifeguard', 'preserver')): 6.4 (n = 10)
# ('5a', '5a', ('flimsy', 'paper'), ('steel', 'strong')): 6.4 (n = 10)
# ('7c', '7c', ('gardener', 'trowel'), ('soldier', 'gun')): 6.4 (n = 10)
# ('7c', '7c', ('maid', 'broom'), ('runner', 'sneakers')): 6.4 (n = 10)
# ('3a', '3a', ('cute', 'adorable'), ('option', 'choice')): 6.4 (n = 10)
# ('9a', '9a', ('closet', 'clothes'), ('cupboard', 'dishes')): 6.4 (n = 10)
# ('4b', '4b', ('hot', 'cold'), ('warm', 'cool')): 6.4 (n = 10)
# ('9a', '9a', ('fridge', 'food'), ('refrigerator', 'food')): 6.4 (n = 10)
# ('9a', '9a', ('school', 'children'), ('store', 'shopper')): 6.4 (n = 10)
# ('3a', '3a', ('glass', 'cup'), ('seat', 'chair')): 6.4 (n = 10)
# ('7c', '7c', ('fairy', 'wand'), ('shooter', 'gun')): 6.4 (n = 10)
# ('3a', '3a', ('candy', 'sweets'), ('music', 'tunes')): 6.4 (n = 10)
# ('3a', '3a', ('beautiful', 'pretty'), ('spin', 'twirl')): 6.38461538462 (n = 13)
# ('1a', '1a', ('dog', 'poodle'), ('politician', 'senator')): 6.38461538462 (n = 13)
# ('7c', '7c', ('driver', 'car'), ('writer', 'pen')): 6.38461538462 (n = 13)
# ('3a', '3a', ('dress', 'frock'), ('spectacles', 'glasses')): 6.38461538462 (n = 13)
# ('1a', '1a', ('appliance', 'refrigerator'), ('dog', 'chihuahua')): 6.38461538462 (n = 13)
# ('3a', '3a', ('boat', 'ship'), ('house', 'dwelling')): 6.38461538462 (n = 13)
# ('7c', '7c', ('drummer', 'sticks'), ('gardener', 'trowel')): 6.38461538462 (n = 13)
# ('4b', '4b', ('ugly', 'pretty'), ('warm', 'cool')): 6.36363636364 (n = 11)
# ('1a', '1a', ('dog', 'poodle'), ('weapon', 'spear')): 6.36363636364 (n = 11)
# ('7c', '7c', ('maid', 'broom'), ('musician', 'instrument')): 6.36363636364 (n = 11)
# ('2a', '2a', ('bird', 'feathers'), ('zebra', 'stripes')): 6.36363636364 (n = 11)
# ('3a', '3a', ('dress', 'frock'), ('kid', 'child')): 6.36363636364 (n = 11)
# ('7c', '7c', ('chef', 'knife'), ('police', 'gun')): 6.36363636364 (n = 11)
# ('3a', '3a', ('bathroom', 'restroom'), ('spectacles', 'glasses')): 6.36363636364 (n = 11)
# ('7c', '7c', ('pitcher', 'baseball'), ('shooter', 'gun')): 6.36363636364 (n = 11)
# ('1a', '1a', ('automobile', 'van'), ('insect', 'ant')): 6.36363636364 (n = 11)
# ('4b', '4b', ('fat', 'thin'), ('tall', 'short')): 6.36363636364 (n = 11)
# ('2a', '2a', ('fish', 'fin'), ('shoe', 'sole')): 6.36363636364 (n = 11)
# ('3a', '3a', ('restroom', 'bathroom'), ('spin', 'twirl')): 6.36363636364 (n = 11)
# ('7c', '7c', ('chemist', 'beaker'), ('gardener', 'trowel')): 6.36363636364 (n = 11)
# ('1a', '1e', ('bird', 'swan'), ('lake', 'Erie')): 6.36363636364 (n = 11)
# ('5a', '5a', ('blanket', 'soft'), ('pillow', 'soft')): 6.36363636364 (n = 11)
# ('4b', '4b', ('big', 'small'), ('fat', 'thin')): 6.36363636364 (n = 11)
# ('3a', '3a', ('cute', 'adorable'), ('old', 'mature')): 6.36363636364 (n = 11)
# ('9a', '9a', ('airplane', 'hangar'), ('fish', 'aquarium')): 6.35714285714 (n = 14)
# ('7c', '7c', ('drummer', 'sticks'), ('fairy', 'wand')): 6.35714285714 (n = 14)
# ('9a', '9a', ('dresser', 'clothes'), ('kitchen', 'food')): 6.35714285714 (n = 14)
# ('3a', '3a', ('restroom', 'bathroom'), ('seat', 'chair')): 6.35294117647 (n = 17)
# ('1a', '1a', ('animal', 'pig'), ('insect', 'ant')): 6.33333333333 (n = 12)
# ('9a', '9a', ('aquarium', 'fish'), ('dresser', 'clothes')): 6.33333333333 (n = 12)
# ('3a', '3a', ('house', 'abode'), ('house', 'dwelling')): 6.33333333333 (n = 12)
# ('3a', '3a', ('boat', 'ship'), ('pants', 'trousers')): 6.33333333333 (n = 12)
# ('7c', '7c', ('police', 'gun'), ('writer', 'pen')): 6.33333333333 (n = 12)
# ('2a', '2a', ('bicycle', 'wheel'), ('fish', 'fin')): 6.33333333333 (n = 12)
# ('3a', '3a', ('bathroom', 'restroom'), ('cute', 'adorable')): 6.33333333333 (n = 12)
# ('1a', '1a', ('animal', 'pig'), ('rodent', 'mouse')): 6.33333333333 (n = 12)
# ('7c', '7c', ('hairdresser', 'comb'), ('shooter', 'gun')): 6.33333333333 (n = 12)
# ('1a', '1a', ('dog', 'poodle'), ('rodent', 'mouse')): 6.33333333333 (n = 12)
# ('9a', '9a', ('library', 'books'), ('space', 'planets')): 6.33333333333 (n = 12)
# ('1a', '1a', ('clothing', 'shirt'), ('weapon', 'spear')): 6.33333333333 (n = 12)
# ('9a', '9a', ('fridge', 'food'), ('library', 'books')): 6.33333333333 (n = 12)
# ('9a', '9a', ('forest', 'trees'), ('hive', 'bees')): 6.33333333333 (n = 12)
# ('7c', '7c', ('chemist', 'beaker'), ('fairy', 'wand')): 6.33333333333 (n = 12)
# ('1a', '1a', ('pet', 'dog'), ('politician', 'senator')): 6.33333333333 (n = 12)
# ('7c', '7c', ('gardener', 'trowel'), ('hairdresser', 'comb')): 6.30769230769 (n = 13)
# ('3a', '3a', ('option', 'choice'), ('pretty', 'beautiful')): 6.30769230769 (n = 13)
# ('3a', '3a', ('careful', 'cautious'), ('pants', 'trousers')): 6.30769230769 (n = 13)
# ('1a', '1a', ('animal', 'pig'), ('pet', 'dog')): 6.30769230769 (n = 13)
# ('3a', '3a', ('boat', 'ship'), ('spectacles', 'glasses')): 6.30769230769 (n = 13)
# ('7c', '7c', ('teacher', 'chalk'), ('writer', 'pen')): 6.3 (n = 10)
# ('3a', '3a', ('option', 'choice'), ('seat', 'chair')): 6.3 (n = 10)
# ('2a', '2a', ('book', 'spine'), ('fish', 'fin')): 6.3 (n = 10)
# ('4b', '4b', ('tall', 'short'), ('thin', 'fat')): 6.3 (n = 10)
# ('4b', '4b', ('bald', 'hairy'), ('dirty', 'clean')): 6.3 (n = 10)
# ('1a', '1a', ('clothing', 'shirt'), ('school', 'university')): 6.3 (n = 10)
# ('9a', '9a', ('airplane', 'hangar'), ('clothes', 'dresser')): 6.3 (n = 10)
# ('7c', '7c', ('doctor', 'stethoscope'), ('driver', 'car')): 6.3 (n = 10)
# ('8a', '8a', ('injury', 'pain'), ('loss', 'grief')): 6.3 (n = 10)
# ('7c', '7c', ('gardener', 'shovel'), ('housekeeper', 'broom')): 6.3 (n = 10)
# ('4c', '4b', ('go', 'stop'), ('smart', 'stupid')): 6.3 (n = 10)
# ('4b', '4b', ('difficult', 'easy'), ('dull', 'bright')): 6.3 (n = 10)
# ('3a', '3a', ('pants', 'trousers'), ('tedious', 'monotonous')): 6.3 (n = 10)
# ('7c', '7c', ('maid', 'broom'), ('teacher', 'chalk')): 6.3 (n = 10)
# ('8a', '8b', ('injury', 'pain'), ('poison', 'illness')): 6.3 (n = 10)
# ('4b', '4b', ('dirty', 'clean'), ('ugly', 'pretty')): 6.3 (n = 10)
# ('9a', '9a', ('closet', 'clothes'), ('library', 'books')): 6.3 (n = 10)
# ('2a', '2a', ('eye', 'lashes'), ('hand', 'finger')): 6.3 (n = 10)
# ('3a', '3a', ('old', 'mature'), ('pants', 'trousers')): 6.3 (n = 10)
# ('1a', '1a', ('appliance', 'refrigerator'), ('rodent', 'mouse')): 6.3 (n = 10)
# ('9a', '9a', ('clothes', 'dresser'), ('fish', 'aquarium')): 6.3 (n = 10)
# ('4b', '4b', ('pretty', 'ugly'), ('thin', 'fat')): 6.3 (n = 10)
# ('7c', '7c', ('surgeon', 'scalpel'), ('teacher', 'chalk')): 6.3 (n = 10)
# ('7c', '7c', ('gardener', 'shovel'), ('pitcher', 'baseball')): 6.3 (n = 10)
# ('1a', '1a', ('appliance', 'refrigerator'), ('weapon', 'spear')): 6.3 (n = 10)
# ('7c', '7c', ('librarian', 'books'), ('shooter', 'gun')): 6.3 (n = 10)
# ('1a', '1a', ('clothing', 'shirt'), ('dog', 'chihuahua')): 6.3 (n = 10)
# ('7c', '7c', ('hairdresser', 'comb'), ('pitcher', 'baseball')): 6.3 (n = 10)
# ('2a', '2a', ('dog', 'tail'), ('shoe', 'sole')): 6.3 (n = 10)
# ('2a', '2a', ('book', 'spine'), ('dog', 'tail')): 6.3 (n = 10)
# ('1a', '1a', ('automobile', 'van'), ('politician', 'senator')): 6.3 (n = 10)
# ('1a', '1a', ('furniture', 'couch'), ('school', 'university')): 6.3 (n = 10)
# ('7c', '7c', ('shooter', 'gun'), ('teacher', 'chalk')): 6.3 (n = 10)
# ('2a', '2a', ('bicycle', 'wheel'), ('zebra', 'stripes')): 6.3 (n = 10)
# ('7c', '7c', ('chemist', 'beaker'), ('shooter', 'gun')): 6.3 (n = 10)
# ('8b', '8a', ('heat', 'sweat'), ('tragedy', 'tears')): 6.3 (n = 10)
# ('3a', '3a', ('house', 'abode'), ('pretty', 'beautiful')): 6.3 (n = 10)
# ('7c', '7c', ('chemist', 'beaker'), ('teacher', 'chalk')): 6.3 (n = 10)
# ('7c', '7c', ('musician', 'instrument'), ('pitcher', 'baseball')): 6.3 (n = 10)
# ('1a', '1a', ('animal', 'carabao'), ('dog', 'poodle')): 6.3 (n = 10)
# ('1a', '1a', ('clothing', 'shirt'), ('dog', 'poodle')): 6.3 (n = 10)
# ('4b', '4b', ('tall', 'short'), ('tough', 'weak')): 6.3 (n = 10)
# ('9a', '9a', ('forest', 'trees'), ('refrigerator', 'food')): 6.3 (n = 10)
# ('2a', '2a', ('eye', 'lashes'), ('fish', 'fin')): 6.3 (n = 10)
# ('1a', '1a', ('car', 'mustang'), ('insect', 'ant')): 6.3 (n = 10)
# ('4b', '4c', ('bad', 'good'), ('charm', 'repulse')): 6.3 (n = 10)
# ('7c', '7c', ('doctor', 'thermometer'), ('drummer', 'sticks')): 6.3 (n = 10)
# ('7c', '7c', ('gardener', 'trowel'), ('lifeguard', 'preserver')): 6.3 (n = 10)
# ('4b', '4b', ('hairy', 'bald'), ('pretty', 'ugly')): 6.3 (n = 10)
# ('7c', '7c', ('maid', 'broom'), ('shopper', 'cart')): 6.3 (n = 10)
# ('1a', '1a', ('art', 'abstract'), ('dog', 'poodle')): 6.3 (n = 10)
# ('1a', '1a', ('animal', 'carabao'), ('weapon', 'spear')): 6.3 (n = 10)
# ('7c', '7c', ('drummer', 'sticks'), ('gardener', 'shovel')): 6.3 (n = 10)
# ('8a', '8a', ('fire', 'burns'), ('germs', 'sickness')): 6.3 (n = 10)
# ('7c', '7c', ('librarian', 'books'), ('policeman', 'handcuffs')): 6.3 (n = 10)
# ('7c', '7c', ('doctor', 'stethoscope'), ('housekeeper', 'broom')): 6.3 (n = 10)
# ('1a', '1a', ('furniture', 'couch'), ('insect', 'ant')): 6.3 (n = 10)
# ('7c', '7c', ('runner', 'sneakers'), ('soldier', 'gun')): 6.3 (n = 10)
# ('4b', '4b', ('big', 'small'), ('smart', 'stupid')): 6.3 (n = 10)
# ('4b', '4c', ('easy', 'difficult'), ('fail', 'succeed')): 6.3 (n = 10)
# ('1a', '1a', ('furniture', 'couch'), ('mammal', 'porpoise')): 6.3 (n = 10)
# ('7c', '7c', ('lifeguard', 'preserver'), ('runner', 'sneakers')): 6.3 (n = 10)
# ('3a', '3a', ('house', 'abode'), ('pants', 'trousers')): 6.3 (n = 10)
# ('5a', '5a', ('athlete', 'fit'), ('murderer', 'evil')): 6.3 (n = 10)
# ('3a', '3a', ('old', 'mature'), ('raise', 'elevate')): 6.3 (n = 10)
# ('10a', '10a', ('love', 'valentine'), ('valentine', 'love')): 6.3 (n = 10)
# ('7c', '7c', ('hairdresser', 'comb'), ('teacher', 'chalk')): 6.3 (n = 10)
# ('9a', '9a', ('classroom', 'students'), ('fridge', 'food')): 6.3 (n = 10)
# ('9a', '9a', ('carton', 'milk'), ('zoo', 'animals')): 6.3 (n = 10)
# ('5a', '5a', ('candy', 'sweet'), ('pizza', 'cheesy')): 6.3 (n = 10)
# ('7c', '7c', ('housekeeper', 'broom'), ('shooter', 'gun')): 6.3 (n = 10)
# ('8a', '8a', ('cold', 'sneeze'), ('sadness', 'tears')): 6.3 (n = 10)
# ('5a', '5a', ('blanket', 'soft'), ('candy', 'sweet')): 6.3 (n = 10)
# ('7c', '7c', ('runner', 'sneakers'), ('writer', 'pen')): 6.3 (n = 10)
# ('7c', '7c', ('gardener', 'trowel'), ('policeman', 'handcuffs')): 6.3 (n = 10)
# ('4b', '4b', ('difficult', 'easy'), ('easy', 'difficult')): 6.3 (n = 10)
# ('9a', '9a', ('airplane', 'hangar'), ('closet', 'clothes')): 6.3 (n = 10)
# ('5a', '5a', ('paper', 'flimsy'), ('steel', 'strong')): 6.3 (n = 10)
# ('9a', '9a', ('aquarium', 'fish'), ('carton', 'milk')): 6.3 (n = 10)
# ('2a', '2a', ('dance', 'step'), ('play', 'act')): 6.3 (n = 10)
# ('7c', '7c', ('driver', 'car'), ('shopper', 'cart')): 6.3 (n = 10)
# ('3a', '3a', ('glass', 'cup'), ('spectacles', 'glasses')): 6.3 (n = 10)
# ('7c', '7c', ('doctor', 'stethoscope'), ('fairy', 'wand')): 6.3 (n = 10)
# ('5a', '5a', ('fire', 'hot'), ('steel', 'tough')): 6.3 (n = 10)
# ('4b', '4b', ('difficult', 'easy'), ('thin', 'fat')): 6.3 (n = 10)
# ('4b', '4b', ('easy', 'difficult'), ('thin', 'fat')): 6.3 (n = 10)
# ('1a', '1a', ('rodent', 'mouse'), ('weather', 'rain')): 6.3 (n = 10)
# ('4b', '4b', ('difficult', 'easy'), ('fat', 'thin')): 6.3 (n = 10)
# ('3a', '3a', ('pants', 'trousers'), ('raise', 'elevate')): 6.3 (n = 10)
# ('4b', '4b', ('difficult', 'easy'), ('good', 'bad')): 6.3 (n = 10)
# ('4b', '4b', ('hot', 'cold'), ('pretty', 'ugly')): 6.3 (n = 10)
# ('3a', '3b', ('house', 'dwelling'), ('pain', 'agony')): 6.3 (n = 10)
# ('7c', '7c', ('librarian', 'books'), ('writer', 'pen')): 6.3 (n = 10)
# ('9a', '9a', ('bathroom', 'toilet'), ('supermarket', 'groceries')): 6.3 (n = 10)
# ('5a', '5a', ('candy', 'sweet'), ('steel', 'strong')): 6.3 (n = 10)
# ('3a', '3b', ('glass', 'cup'), ('shriek', 'scream')): 6.29411764706 (n = 17)
# ('7c', '7c', ('gardener', 'trowel'), ('police', 'gun')): 6.28571428571 (n = 14)
# ('7c', '7c', ('policeman', 'handcuffs'), ('writer', 'pen')): 6.27272727273 (n = 11)
# ('3a', '3a', ('house', 'dwelling'), ('restroom', 'bathroom')): 6.27272727273 (n = 11)
# ('8a', '8a', ('fire', 'burns'), ('hit', 'injury')): 6.27272727273 (n = 11)
# ('3a', '3a', ('careful', 'cautious'), ('cute', 'adorable')): 6.27272727273 (n = 11)
# ('1a', '1a', ('dog', 'chihuahua'), ('insect', 'ant')): 6.27272727273 (n = 11)
# ('4b', '4b', ('bad', 'good'), ('ugly', 'pretty')): 6.27272727273 (n = 11)
# ('10a', '10a', ('rain', 'storm'), ('smoke', 'fire')): 6.27272727273 (n = 11)
# ('7c', '7c', ('hairdresser', 'comb'), ('police', 'gun')): 6.27272727273 (n = 11)
# ('7c', '7c', ('gardener', 'shovel'), ('hairdresser', 'comb')): 6.27272727273 (n = 11)
# ('3a', '3a', ('dress', 'frock'), ('pants', 'trousers')): 6.27272727273 (n = 11)
# ('7c', '7c', ('doctor', 'thermometer'), ('gardener', 'shovel')): 6.27272727273 (n = 11)
# ('9a', '9a', ('bus', 'passengers'), ('classroom', 'students')): 6.27272727273 (n = 11)
# ('2a', '2a', ('bicycle', 'wheel'), ('boat', 'motor')): 6.27272727273 (n = 11)
# ('1a', '1a', ('animal', 'pig'), ('politician', 'senator')): 6.27272727273 (n = 11)
# ('3b', '3a', ('happiness', 'joy'), ('old', 'mature')): 6.27272727273 (n = 11)
# ('3a', '3b', ('clean', 'tidy'), ('shriek', 'scream')): 6.27272727273 (n = 11)
# ('3a', '3a', ('bathroom', 'restroom'), ('cellphone', 'mobile')): 6.27272727273 (n = 11)
# ('7c', '7c', ('doctor', 'stethoscope'), ('teacher', 'chalk')): 6.27272727273 (n = 11)
# ('1a', '1a', ('dog', 'chihuahua'), ('politician', 'senator')): 6.27272727273 (n = 11)
# ('9a', '9a', ('fridge', 'food'), ('garden', 'flower')): 6.27272727273 (n = 11)
# ('7c', '7c', ('pitcher', 'baseball'), ('police', 'gun')): 6.27272727273 (n = 11)
# ('2a', '2a', ('computer', 'chip'), ('shoe', 'sole')): 6.27272727273 (n = 11)
# ('7c', '7c', ('chef', 'knife'), ('drummer', 'sticks')): 6.27272727273 (n = 11)
# ('5a', '5a', ('pillow', 'soft'), ('snow', 'cold')): 6.27272727273 (n = 11)
# ('9a', '9a', ('forest', 'trees'), ('school', 'children')): 6.27272727273 (n = 11)
# ('1a', '1a', ('dog', 'chihuahua'), ('furniture', 'couch')): 6.27272727273 (n = 11)
# ('7c', '7c', ('shopper', 'cart'), ('surgeon', 'scalpel')): 6.27272727273 (n = 11)
# ('7c', '7c', ('policeman', 'handcuffs'), ('soldier', 'gun')): 6.27272727273 (n = 11)
# ('1a', '1a', ('bird', 'swan'), ('car', 'mustang')): 6.27272727273 (n = 11)
# ('7c', '7c', ('drummer', 'sticks'), ('shopper', 'cart')): 6.27272727273 (n = 11)
# ('3a', '3a', ('house', 'dwelling'), ('spectacles', 'glasses')): 6.25 (n = 12)
# ('4b', '4b', ('thin', 'fat'), ('tough', 'weak')): 6.25 (n = 12)
# ('1a', '1a', ('animal', 'pig'), ('furniture', 'couch')): 6.25 (n = 12)
# ('1a', '1a', ('dog', 'poodle'), ('furniture', 'couch')): 6.25 (n = 12)
# ('7c', '7c', ('chef', 'knife'), ('musician', 'instrument')): 6.25 (n = 12)
# ('9a', '9a', ('bank', 'money'), ('zoo', 'animals')): 6.25 (n = 12)
# ('5a', '5a', ('clay', 'malleable'), ('steel', 'tough')): 6.25 (n = 12)
# ('2a', '2a', ('bicycle', 'wheel'), ('shoe', 'sole')): 6.25 (n = 12)
# ('7c', '7c', ('doctor', 'stethoscope'), ('police', 'gun')): 6.25 (n = 12)
# ('8a', '8a', ('accident', 'damage'), ('injury', 'pain')): 6.25 (n = 12)
# ('3a', '3a', ('pants', 'trousers'), ('run', 'sprint')): 6.25 (n = 12)
# ('4b', '4c', ('hairy', 'bald'), ('peace', 'war')): 6.25 (n = 12)
# ('3a', '3a', ('kid', 'child'), ('spin', 'twirl')): 6.25 (n = 12)
# ('7c', '7c', ('housekeeper', 'broom'), ('shopper', 'cart')): 6.25 (n = 12)
# ('3a', '3a', ('music', 'tunes'), ('pretty', 'beautiful')): 6.23529411765 (n = 17)
# ('1a', '1a', ('school', 'university'), ('weapon', 'spear')): 6.23529411765 (n = 17)
# ('3a', '3a', ('bathroom', 'restroom'), ('pretty', 'beautiful')): 6.23076923077 (n = 13)
# ('3a', '3b', ('cute', 'adorable'), ('movie', 'film')): 6.23076923077 (n = 13)
# ('8a', '8a', ('explosion', 'damage'), ('loss', 'grief')): 6.23076923077 (n = 13)
# ('3a', '3a', ('kid', 'child'), ('raise', 'elevate')): 6.23076923077 (n = 13)
# ('7c', '7c', ('barber', 'scissors'), ('gardener', 'trowel')): 6.23076923077 (n = 13)
# ('7c', '7c', ('gardener', 'shovel'), ('runner', 'sneakers')): 6.21428571429 (n = 14)
# ('1a', '1a', ('color', 'red'), ('politician', 'senator')): 6.2 (n = 10)
# ('4b', '4b', ('dark', 'light'), ('ugly', 'pretty')): 6.2 (n = 10)
# ('4b', '4b', ('pretty', 'ugly'), ('ugly', 'pretty')): 6.2 (n = 10)
# ('5a', '5a', ('snow', 'cold'), ('steel', 'tough')): 6.2 (n = 10)
# ('3a', '3a', ('clean', 'tidy'), ('cute', 'adorable')): 6.2 (n = 10)
# ('7c', '7c', ('chef', 'knife'), ('gardener', 'shovel')): 6.2 (n = 10)
# ('7c', '7c', ('gardener', 'shovel'), ('lawyer', 'books')): 6.2 (n = 10)
# ('4b', '4b', ('dirty', 'clean'), ('thin', 'fat')): 6.2 (n = 10)
# ('2a', '2a', ('jeans', 'zipper'), ('shoe', 'sole')): 6.2 (n = 10)
# ('5a', '5a', ('light', 'bright'), ('pizza', 'cheesy')): 6.2 (n = 10)
# ('3a', '3a', ('music', 'tunes'), ('spectacles', 'glasses')): 6.2 (n = 10)
# ('9a', '9a', ('classroom', 'students'), ('hangar', 'airplane')): 6.2 (n = 10)
# ('4b', '4b', ('beautiful', 'hideous'), ('dark', 'light')): 6.2 (n = 10)
# ('7c', '7c', ('fairy', 'wand'), ('housekeeper', 'broom')): 6.2 (n = 10)
# ('5a', '5a', ('dog', 'furry'), ('pillow', 'soft')): 6.2 (n = 10)
# ('8a', '8a', ('run', 'sweat'), ('sadness', 'tears')): 6.2 (n = 10)
# ('7c', '7c', ('maid', 'broom'), ('writer', 'pen')): 6.2 (n = 10)
# ('9a', '9a', ('classroom', 'students'), ('space', 'planets')): 6.2 (n = 10)
# ('9a', '9a', ('bank', 'money'), ('school', 'children')): 6.2 (n = 10)
# ('7c', '7c', ('fairy', 'wand'), ('maid', 'broom')): 6.2 (n = 10)
# ('7c', '7c', ('housekeeper', 'broom'), ('musician', 'instrument')): 6.2 (n = 10)
# ('9a', '9a', ('bank', 'money'), ('classroom', 'students')): 6.2 (n = 10)
# ('7c', '7c', ('housekeeper', 'broom'), ('police', 'gun')): 6.2 (n = 10)
# ('7c', '7c', ('doctor', 'stethoscope'), ('shooter', 'gun')): 6.2 (n = 10)
# ('7c', '7c', ('barber', 'scissors'), ('fairy', 'wand')): 6.2 (n = 10)
# ('5a', '5a', ('fire', 'hot'), ('murderer', 'evil')): 6.2 (n = 10)
# ('2a', '2a', ('bouquet', 'flower'), ('bunch', 'grape')): 6.2 (n = 10)
# ('8a', '8a', ('explosion', 'damage'), ('sex', 'pregnancy')): 6.2 (n = 10)
# ('2a', '2b', ('hand', 'finger'), ('troop', 'soldier')): 6.2 (n = 10)
# ('5a', '5a', ('candy', 'sweet'), ('pillow', 'soft')): 6.2 (n = 10)
# ('4b', '4b', ('bald', 'hairy'), ('bright', 'dark')): 6.2 (n = 10)
# ('6c', '6a', ('depression', 'joy'), ('heat', 'cold')): 6.2 (n = 10)
# ('9a', '9a', ('hangar', 'airplane'), ('supermarket', 'groceries')): 6.2 (n = 10)
# ('2a', '2a', ('bird', 'wings'), ('tastebuds', 'tongue')): 6.2 (n = 10)
# ('2a', '2a', ('bouquet', 'flower'), ('foot', 'toe')): 6.2 (n = 10)
# ('7c', '7c', ('barber', 'scissors'), ('runner', 'sneakers')): 6.2 (n = 10)
# ('1a', '1e', ('dog', 'chihuahua'), ('ocean', 'Pacific')): 6.2 (n = 10)
# ('1a', '1a', ('bird', 'swan'), ('school', 'university')): 6.2 (n = 10)
# ('1a', '1a', ('automobile', 'van'), ('weapon', 'spear')): 6.2 (n = 10)
# ('3a', '3a', ('glass', 'cup'), ('pants', 'trousers')): 6.2 (n = 10)
# ('3a', '3a', ('cute', 'adorable'), ('kid', 'child')): 6.2 (n = 10)
# ('7c', '7c', ('doctor', 'stethoscope'), ('surgeon', 'scalpel')): 6.2 (n = 10)
# ('9a', '9a', ('closet', 'clothes'), ('zoo', 'animals')): 6.2 (n = 10)
# ('1a', '1a', ('animal', 'pig'), ('appliance', 'refrigerator')): 6.2 (n = 10)
# ('7c', '7c', ('musician', 'instrument'), ('teacher', 'chalk')): 6.2 (n = 10)
# ('8a', '8a', ('sadness', 'tears'), ('sex', 'pregnancy')): 6.2 (n = 10)
# ('4b', '4b', ('good', 'bad'), ('hot', 'cold')): 6.2 (n = 10)
# ('2a', '2a', ('tastebuds', 'tongue'), ('toe', 'foot')): 6.2 (n = 10)
# ('5a', '5a', ('blanket', 'soft'), ('clay', 'malleable')): 6.2 (n = 10)
# ('9a', '9a', ('cupboard', 'dishes'), ('supermarket', 'groceries')): 6.2 (n = 10)
# ('7c', '7c', ('barber', 'scissors'), ('soldier', 'gun')): 6.2 (n = 10)
# ('4b', '4b', ('big', 'small'), ('hairy', 'bald')): 6.2 (n = 10)
# ('7c', '7c', ('chef', 'knife'), ('lawyer', 'books')): 6.2 (n = 10)
# ('9a', '9a', ('school', 'student'), ('store', 'shopper')): 6.2 (n = 10)
# ('9a', '9a', ('classroom', 'students'), ('cupboard', 'dishes')): 6.2 (n = 10)
# ('3a', '3a', ('make', 'manufacture'), ('run', 'sprint')): 6.2 (n = 10)
# ('1a', '1a', ('animal', 'carabao'), ('bird', 'swan')): 6.2 (n = 10)
# ('3a', '3a', ('cellphone', 'mobile'), ('kid', 'child')): 6.2 (n = 10)
# ('3a', '3a', ('candy', 'sweets'), ('tedious', 'monotonous')): 6.2 (n = 10)
# ('9a', '9a', ('cupboard', 'dishes'), ('space', 'planets')): 6.2 (n = 10)
# ('2a', '2a', ('bird', 'wings'), ('dog', 'tail')): 6.2 (n = 10)
# ('7c', '7c', ('pitcher', 'baseball'), ('policeman', 'handcuffs')): 6.2 (n = 10)
# ('7c', '7c', ('chemist', 'beaker'), ('drummer', 'sticks')): 6.2 (n = 10)
# ('8a', '8a', ('tragedy', 'tears'), ('workout', 'sweat')): 6.2 (n = 10)
# ('3a', '3a', ('kid', 'child'), ('pants', 'trousers')): 6.2 (n = 10)
# ('7c', '7c', ('chemist', 'beaker'), ('musician', 'instrument')): 6.2 (n = 10)
# ('4b', '4b', ('beautiful', 'hideous'), ('good', 'bad')): 6.2 (n = 10)
# ('4b', '4b', ('smart', 'stupid'), ('tough', 'weak')): 6.2 (n = 10)
# ('5a', '5a', ('light', 'bright'), ('snow', 'cold')): 6.2 (n = 10)
# ('9a', '9a', ('hive', 'bees'), ('supermarket', 'groceries')): 6.2 (n = 10)
# ('3a', '3a', ('careful', 'cautious'), ('make', 'manufacture')): 6.2 (n = 10)
# ('7c', '7c', ('drummer', 'sticks'), ('shooter', 'gun')): 6.2 (n = 10)
# ('3a', '3a', ('kid', 'child'), ('spectacles', 'glasses')): 6.2 (n = 10)
# ('7c', '7c', ('maid', 'broom'), ('policeman', 'handcuffs')): 6.2 (n = 10)
# ('4b', '4b', ('bald', 'hairy'), ('beautiful', 'hideous')): 6.18181818182 (n = 11)
# ('4b', '4b', ('bad', 'good'), ('excited', 'bored')): 6.18181818182 (n = 11)
# ('3a', '3b', ('cute', 'adorable'), ('disdain', 'hatred')): 6.18181818182 (n = 11)
# ('7c', '7c', ('pitcher', 'baseball'), ('soldier', 'gun')): 6.18181818182 (n = 11)
# ('2a', '2a', ('eye', 'lashes'), ('foot', 'toe')): 6.18181818182 (n = 11)
# ('9a', '9a', ('aquarium', 'fish'), ('school', 'student')): 6.18181818182 (n = 11)
# ('1a', '1a', ('clothing', 'shirt'), ('insect', 'ant')): 6.18181818182 (n = 11)
# ('7c', '7c', ('doctor', 'thermometer'), ('housekeeper', 'broom')): 6.18181818182 (n = 11)
# ('1a', '1a', ('animal', 'carabao'), ('appliance', 'refrigerator')): 6.18181818182 (n = 11)
# ('3a', '3b', ('bathroom', 'restroom'), ('giggle', 'laugh')): 6.18181818182 (n = 11)
# ('9a', '9a', ('cupboard', 'dishes'), ('kitchen', 'food')): 6.18181818182 (n = 11)
# ('7c', '7c', ('gardener', 'shovel'), ('musician', 'instrument')): 6.18181818182 (n = 11)
# ('3a', '3a', ('kid', 'child'), ('restroom', 'bathroom')): 6.18181818182 (n = 11)
# ('7c', '7c', ('barber', 'scissors'), ('doctor', 'thermometer')): 6.18181818182 (n = 11)
# ('9a', '9a', ('refrigerator', 'food'), ('school', 'children')): 6.18181818182 (n = 11)
# ('3a', '3a', ('clean', 'tidy'), ('raise', 'elevate')): 6.18181818182 (n = 11)
# ('5a', '5a', ('fire', 'heat'), ('snow', 'cold')): 6.18181818182 (n = 11)
# ('1a', '1a', ('furniture', 'couch'), ('politician', 'senator')): 6.18181818182 (n = 11)
# ('6a', '6a', ('empty', 'full'), ('hungry', 'satiety')): 6.18181818182 (n = 11)
# ('3a', '3a', ('make', 'manufacture'), ('raise', 'elevate')): 6.18181818182 (n = 11)
# ('3a', '3b', ('careful', 'cautious'), ('clever', 'ingenious')): 6.18181818182 (n = 11)
# ('4b', '4b', ('fast', 'slow'), ('good', 'bad')): 6.18181818182 (n = 11)
# ('9a', '9a', ('closet', 'clothes'), ('forest', 'trees')): 6.18181818182 (n = 11)
# ...
# ('10a', '10c', ('camera', 'distrust'), ('face', 'profile')): 1.7 (n = 10)
# ('3a', '6a', ('boat', 'ship'), ('forgiving', 'vengeful')): 1.7 (n = 10)
# ('10a', '10a', ('camera', 'distrust'), ('smoke', 'fire')): 1.7 (n = 10)
# ('6a', '6a', ('beauty', 'unpleasant'), ('object', 'tangible')): 1.7 (n = 10)
# ('4b', '5a', ('hot', 'cold'), ('sunburn', 'painful')): 1.7 (n = 10)
# ('2a', '6a', ('fish', 'fin'), ('solid', 'liquid')): 1.7 (n = 10)
# ('10a', '10a', ('distrust', 'camera'), ('moisture', 'cloud')): 1.7 (n = 10)
# ('6a', '6c', ('object', 'tangible'), ('poor', 'wealth')): 1.7 (n = 10)
# ('4b', '5a', ('bad', 'good'), ('pillow', 'soft')): 1.7 (n = 10)
# ('2a', '4b', ('city', 'block'), ('excited', 'bored')): 1.7 (n = 10)
# ('6a', '8a', ('color', 'invisible'), ('loss', 'grief')): 1.7 (n = 10)
# ('4b', '2a', ('bright', 'dark'), ('freezer', 'ice')): 1.7 (n = 10)
# ('1a', '4b', ('dog', 'chihuahua'), ('salty', 'sweet')): 1.7 (n = 10)
# ('1a', '6a', ('appliance', 'refrigerator'), ('enthusiasm', 'apathetic')): 1.7 (n = 10)
# ('9a', '9g', ('hive', 'bees'), ('parenthood', 'laughter')): 1.7 (n = 10)
# ('4b', '1a', ('easy', 'difficult'), ('weather', 'rain')): 1.7 (n = 10)
# ('2a', '4b', ('city', 'block'), ('difficult', 'easy')): 1.7 (n = 10)
# ('9a', '6a', ('garage', 'mechanic'), ('killer', 'empathetic')): 1.7 (n = 10)
# ('10a', '10a', ('citation', 'violation'), ('distrust', 'camera')): 1.7 (n = 10)
# ('4b', '1a', ('dull', 'bright'), ('hair', 'brown')): 1.7 (n = 10)
# ('5a', '4b', ('dog', 'furry'), ('hungry', 'satiated')): 1.7 (n = 10)
# ('6a', '6a', ('object', 'tangible'), ('voice', 'mute')): 1.7 (n = 10)
# ('4b', '8a', ('hot', 'cold'), ('tragedy', 'tears')): 1.7 (n = 10)
# ('10a', '10a', ('cry', 'help'), ('distrust', 'camera')): 1.7 (n = 10)
# ('6a', '8a', ('integrity', 'dishonest'), ('sadness', 'tears')): 1.7 (n = 10)
# ('5a', '2a', ('bone', 'brittle'), ('computer', 'chip')): 1.7 (n = 10)
# ('2a', '3a', ('bunch', 'grape'), ('raise', 'elevate')): 1.69230769231 (n = 13)
# ('10a', '2a', ('distrust', 'camera'), ('hand', 'finger')): 1.69230769231 (n = 13)
# ('4b', '3a', ('pretty', 'ugly'), ('spin', 'twirl')): 1.69230769231 (n = 13)
# ('10a', '10a', ('camera', 'distrust'), ('love', 'valentine')): 1.66666666667 (n = 12)
# ('10a', '10a', ('camera', 'distrust'), ('flag', 'nation')): 1.66666666667 (n = 12)
# ('4b', '1a', ('easy', 'difficult'), ('insect', 'ant')): 1.66666666667 (n = 12)
# ('10a', '10a', ('distrust', 'camera'), ('pregnancy', 'baby')): 1.66666666667 (n = 12)
# ('3a', '4b', ('cellphone', 'mobile'), ('sleepy', 'energized')): 1.66666666667 (n = 12)
# ('4b', '2a', ('big', 'small'), ('freezer', 'ice')): 1.66666666667 (n = 12)
# ('4b', '2a', ('bald', 'hairy'), ('book', 'spine')): 1.63636363636 (n = 11)
# ('10a', '10c', ('camera', 'distrust'), ('screenplay', 'movie')): 1.63636363636 (n = 11)
# ('4b', '10a', ('black', 'white'), ('crossbones', 'poison')): 1.63636363636 (n = 11)
# ('4b', '1a', ('bored', 'excited'), ('dog', 'chihuahua')): 1.63636363636 (n = 11)
# ('10a', '10a', ('distrust', 'camera'), ('valentine', 'love')): 1.63636363636 (n = 11)
# ('4b', '3a', ('fat', 'thin'), ('house', 'abode')): 1.63636363636 (n = 11)
# ('4b', '4c', ('hungry', 'satiated'), ('poop', 'eat')): 1.63636363636 (n = 11)
# ('4b', '8a', ('dirty', 'clean'), ('study', 'learning')): 1.63636363636 (n = 11)
# ('2a', '4b', ('cat', 'whiskers'), ('dark', 'light')): 1.63636363636 (n = 11)
# ('2a', '4b', ('bicycle', 'wheel'), ('fast', 'slow')): 1.63636363636 (n = 11)
# ('4b', '2a', ('big', 'small'), ('fish', 'fin')): 1.6 (n = 10)
# ('6a', '6a', ('ecstasy', 'sad'), ('object', 'tangible')): 1.6 (n = 10)
# ('10a', '10a', ('distrust', 'camera'), ('flag', 'nation')): 1.6 (n = 10)
# ('2a', '4b', ('computer', 'chip'), ('dirty', 'clean')): 1.6 (n = 10)
# ('4b', '3a', ('hot', 'cold'), ('option', 'choice')): 1.6 (n = 10)
# ('10a', '10a', ('bell', 'dinner'), ('camera', 'distrust')): 1.6 (n = 10)
# ('8b', '8a', ('fill', 'emptiness'), ('tragedy', 'tears')): 1.6 (n = 10)
# ('1a', '4b', ('animal', 'pig'), ('fat', 'thin')): 1.6 (n = 10)
# ('7c', '5a', ('chemist', 'beaker'), ('paper', 'flimsy')): 1.6 (n = 10)
# ('3a', '4b', ('bathroom', 'restroom'), ('fat', 'thin')): 1.6 (n = 10)
# ('2a', '4b', ('computer', 'chip'), ('sleepy', 'energized')): 1.6 (n = 10)
# ('4b', '1a', ('dirty', 'clean'), ('insect', 'ant')): 1.6 (n = 10)
# ('2a', '6a', ('eye', 'lashes'), ('violence', 'love')): 1.6 (n = 10)
# ('4b', '9a', ('bad', 'good'), ('bank', 'money')): 1.6 (n = 10)
# ('6a', '6a', ('best', 'inferior'), ('object', 'tangible')): 1.6 (n = 10)
# ('10a', '10a', ('camera', 'distrust'), ('moisture', 'cloud')): 1.6 (n = 10)
# ('10a', '10c', ('camera', 'distrust'), ('juice', 'fruit')): 1.6 (n = 10)
# ('10a', '7c', ('camera', 'distrust'), ('lawyer', 'books')): 1.6 (n = 10)
# ('5a', '4b', ('professor', 'intellectual'), ('smart', 'stupid')): 1.6 (n = 10)
# ('4b', '1a', ('chilly', 'warm'), ('sweater', 'knit')): 1.6 (n = 10)
# ('6a', '2a', ('ecstasy', 'sad'), ('shoe', 'sole')): 1.6 (n = 10)
# ('4b', '2a', ('bad', 'good'), ('eye', 'lashes')): 1.6 (n = 10)
# ('10a', '10a', ('cross', 'faith'), ('distrust', 'camera')): 1.6 (n = 10)
# ('10a', '10a', ('distrust', 'camera'), ('handshake', 'agreement')): 1.6 (n = 10)
# ('4b', '10a', ('ugly', 'pretty'), ('wrinkle', 'age')): 1.6 (n = 10)
# ('3a', '4b', ('kid', 'child'), ('ugly', 'pretty')): 1.6 (n = 10)
# ('4b', '8a', ('pretty', 'ugly'), ('sweat', 'run')): 1.6 (n = 10)
# ('4b', '9a', ('bright', 'dark'), ('space', 'planets')): 1.6 (n = 10)
# ('6a', '5a', ('bounty', 'scarce'), ('steel', 'tough')): 1.6 (n = 10)
# ('4b', '1a', ('bald', 'hairy'), ('dollar', 'currency')): 1.6 (n = 10)
# ('4b', '3a', ('big', 'small'), ('candy', 'sweets')): 1.58333333333 (n = 12)
# ('10a', '10a', ('distrust', 'camera'), ('thunder', 'lightning')): 1.58333333333 (n = 12)
# ('6a', '9a', ('fire', 'cold'), ('library', 'books')): 1.57142857143 (n = 14)
# ('10a', '10a', ('camera', 'distrust'), ('green', 'go')): 1.54545454545 (n = 11)
# ('4b', '5a', ('bad', 'good'), ('steel', 'strength')): 1.54545454545 (n = 11)
# ('6c', '6a', ('dance', 'silence'), ('tidy', 'messy')): 1.54545454545 (n = 11)
# ('8a', '6a', ('accident', 'damage'), ('classic', 'trendy')): 1.54545454545 (n = 11)
# ('4b', '3a', ('dirty', 'clean'), ('tedious', 'monotonous')): 1.53846153846 (n = 13)
# ('1a', '4b', ('bread', 'wheat'), ('smart', 'stupid')): 1.53846153846 (n = 13)
# ('4b', '3a', ('sleepy', 'energized'), ('spectacles', 'glasses')): 1.52941176471 (n = 17)
# ('1a', '4b', ('clothing', 'shirt'), ('ugly', 'pretty')): 1.52941176471 (n = 17)
# ('4b', '3a', ('big', 'small'), ('house', 'abode')): 1.51851851852 (n = 27)
# ('2a', '2b', ('fish', 'fin'), ('herd', 'elephant')): 1.5 (n = 12)
# ('10a', '10a', ('camera', 'distrust'), ('cross', 'christianity')): 1.5 (n = 12)
# ('4b', '5a', ('pretty', 'ugly'), ('steel', 'strength')): 1.5 (n = 12)
# ('4b', '3a', ('easy', 'difficult'), ('pants', 'trousers')): 1.5 (n = 12)
# ('3a', '4b', ('cellphone', 'mobile'), ('ugly', 'pretty')): 1.5 (n = 12)
# ('4c', '4b', ('eat', 'poop'), ('tough', 'weak')): 1.5 (n = 10)
# ('6a', '6a', ('honest', 'liar'), ('object', 'tangible')): 1.5 (n = 10)
# ('1a', '4b', ('animal', 'pig'), ('sleepy', 'energized')): 1.5 (n = 10)
# ('4b', '2a', ('black', 'white'), ('city', 'block')): 1.5 (n = 10)
# ('2a', '4b', ('computer', 'chip'), ('excited', 'bored')): 1.5 (n = 10)
# ('1a', '4b', ('bird', 'swan'), ('ugly', 'pretty')): 1.5 (n = 10)
# ('4b', '3a', ('difficult', 'easy'), ('sleep', 'doze')): 1.5 (n = 10)
# ('10a', '10a', ('camera', 'distrust'), ('rain', 'storm')): 1.5 (n = 10)
# ('4b', '7c', ('dirty', 'clean'), ('shooter', 'gun')): 1.5 (n = 10)
# ('7d', '7c', ('forgive', 'sin'), ('runner', 'sneakers')): 1.5 (n = 10)
# ('2a', '6a', ('computer', 'mouse'), ('solid', 'liquid')): 1.5 (n = 10)
# ('4b', '1a', ('dirty', 'clean'), ('oak', 'tree')): 1.5 (n = 10)
# ('4b', '1a', ('bald', 'hairy'), ('weapon', 'spear')): 1.5 (n = 10)
# ('7d', '7c', ('clean', 'house'), ('lifeguard', 'preserver')): 1.5 (n = 10)
# ('8a', '6a', ('explosion', 'damage'), ('tidy', 'messy')): 1.5 (n = 10)
# ('4b', '3a', ('dull', 'bright'), ('house', 'dwelling')): 1.5 (n = 10)
# ('4b', '2a', ('dark', 'light'), ('freezer', 'ice')): 1.5 (n = 10)
# ('4b', '1a', ('big', 'small'), ('wheat', 'bread')): 1.5 (n = 10)
# ('6a', '6a', ('object', 'tangible'), ('solid', 'liquid')): 1.5 (n = 10)
# ('4b', '7c', ('bad', 'good'), ('doctor', 'stethoscope')): 1.5 (n = 10)
# ('6a', '10a', ('best', 'inferior'), ('surgery', 'hospital')): 1.5 (n = 10)
# ('4b', '3a', ('dull', 'bright'), ('spin', 'twirl')): 1.5 (n = 10)
# ('4b', '2a', ('hairy', 'bald'), ('zebra', 'stripes')): 1.5 (n = 10)
# ('7c', '6a', ('doctor', 'stethoscope'), ('speed', 'slow')): 1.5 (n = 10)
# ('10a', '10a', ('camera', 'distrust'), ('surgery', 'hospital')): 1.5 (n = 10)
# ('6a', '3a', ('charisma', 'bland'), ('sleep', 'doze')): 1.5 (n = 10)
# ('4b', '2a', ('excited', 'bored'), ('freezer', 'ice')): 1.5 (n = 10)
# ('4b', '2a', ('bald', 'hairy'), ('boat', 'motor')): 1.5 (n = 10)
# ('3a', '4b', ('kid', 'child'), ('tall', 'short')): 1.5 (n = 10)
# ('6a', '5a', ('best', 'inferior'), ('candy', 'sweet')): 1.5 (n = 10)
# ('4b', '7c', ('big', 'small'), ('hairdresser', 'comb')): 1.5 (n = 10)
# ('10a', '6a', ('crossbones', 'poison'), ('sight', 'invisible')): 1.5 (n = 10)
# ('4b', '2a', ('fast', 'slow'), ('movie', 'scene')): 1.5 (n = 10)
# ('4b', '2a', ('difficult', 'easy'), ('jeans', 'zipper')): 1.5 (n = 10)
# ('4b', '3a', ('excited', 'bored'), ('glass', 'cup')): 1.5 (n = 10)
# ('4b', '1a', ('bright', 'dark'), ('song', 'opera')): 1.5 (n = 10)
# ('6a', '6a', ('object', 'tangible'), ('violence', 'love')): 1.46153846154 (n = 13)
# ('5a', '6a', ('intellectual', 'professor'), ('solid', 'liquid')): 1.45454545455 (n = 11)
# ('1a', '4b', ('automobile', 'van'), ('bald', 'hairy')): 1.45454545455 (n = 11)
# ('9a', '4b', ('clothes', 'dresser'), ('good', 'bad')): 1.45454545455 (n = 11)
# ('2a', '6a', ('hand', 'finger'), ('tidy', 'messy')): 1.45454545455 (n = 11)
# ('3a', '4b', ('bathroom', 'restroom'), ('excited', 'bored')): 1.45454545455 (n = 11)
# ('2a', '4b', ('play', 'act'), ('warm', 'cool')): 1.45454545455 (n = 11)
# ('3a', '4b', ('cute', 'adorable'), ('ugly', 'pretty')): 1.45454545455 (n = 11)
# ('6a', '7c', ('liar', 'honest'), ('shopper', 'cart')): 1.42857142857 (n = 14)
# ('6a', '9a', ('sight', 'invisible'), ('store', 'shopper')): 1.42857142857 (n = 14)
# ('2a', '4b', ('bedroom', 'bed'), ('sleepy', 'energized')): 1.41666666667 (n = 12)
# ('1a', '4b', ('color', 'red'), ('salty', 'sweet')): 1.41666666667 (n = 12)
# ('4b', '3a', ('bad', 'good'), ('cellphone', 'mobile')): 1.41176470588 (n = 17)
# ('3a', '4b', ('bathroom', 'restroom'), ('ugly', 'pretty')): 1.41176470588 (n = 17)
# ('4b', '3a', ('dark', 'light'), ('kid', 'child')): 1.41176470588 (n = 17)
# ('4b', '2a', ('bad', 'good'), ('foot', 'toe')): 1.41176470588 (n = 17)
# ('10a', '10a', ('distrust', 'camera'), ('surgery', 'hospital')): 1.4 (n = 10)
# ('4b', '2a', ('bright', 'dark'), ('play', 'act')): 1.4 (n = 10)
# ('9a', '4b', ('library', 'books'), ('ugly', 'pretty')): 1.4 (n = 10)
# ('2a', '6a', ('bird', 'wings'), ('killer', 'empathetic')): 1.4 (n = 10)
# ('1a', '6a', ('oak', 'tree'), ('violence', 'love')): 1.4 (n = 10)
# ('2a', '10a', ('bedroom', 'bed'), ('camera', 'distrust')): 1.4 (n = 10)
# ('6a', '7c', ('best', 'inferior'), ('gardener', 'trowel')): 1.4 (n = 10)
# ('4b', '9a', ('black', 'white'), ('school', 'student')): 1.4 (n = 10)
# ('1a', '4b', ('insect', 'ant'), ('pretty', 'ugly')): 1.4 (n = 10)
# ('4b', '2a', ('bright', 'dark'), ('bunch', 'grape')): 1.4 (n = 10)
# ('4b', '10a', ('ugly', 'pretty'), ('valentine', 'love')): 1.4 (n = 10)
# ('6a', '9a', ('diseased', 'health'), ('fridge', 'food')): 1.4 (n = 10)
# ('4b', '2a', ('dark', 'light'), ('toe', 'foot')): 1.4 (n = 10)
# ('3a', '4b', ('beautiful', 'pretty'), ('sleepy', 'energized')): 1.4 (n = 10)
# ('4b', '3a', ('chilly', 'warm'), ('restroom', 'bathroom')): 1.4 (n = 10)
# ('2a', '4b', ('dance', 'step'), ('tall', 'short')): 1.4 (n = 10)
# ('5a', '4b', ('steel', 'tough'), ('tough', 'weak')): 1.4 (n = 10)
# ('4b', '3a', ('excited', 'bored'), ('spectacles', 'glasses')): 1.4 (n = 10)
# ('8a', '8b', ('boredom', 'repetition'), ('fat', 'exercise')): 1.4 (n = 10)
# ('9a', '9g', ('milk', 'carton'), ('parenthood', 'laughter')): 1.4 (n = 10)
# ('4b', '1a', ('bad', 'good'), ('car', 'mustang')): 1.4 (n = 10)
# ('4b', '3a', ('tall', 'short'), ('urban', 'city')): 1.4 (n = 10)
# ('6a', '8a', ('fire', 'cold'), ('showering', 'cleanliness')): 1.4 (n = 10)
# ('4b', '7c', ('bored', 'excited'), ('lifeguard', 'preserver')): 1.4 (n = 10)
# ('1a', '6a', ('bird', 'swan'), ('sensitivity', 'boorish')): 1.36363636364 (n = 11)
# ('4b', '8a', ('excited', 'bored'), ('sweat', 'run')): 1.36363636364 (n = 11)
# ('2a', '6a', ('eye', 'lashes'), ('liquid', 'solid')): 1.35714285714 (n = 14)
# ('1a', '4b', ('couch', 'furniture'), ('tough', 'weak')): 1.35294117647 (n = 17)
# ('4b', '1a', ('fat', 'thin'), ('insect', 'ant')): 1.35294117647 (n = 17)
# ('4b', '9a', ('beautiful', 'hideous'), ('hive', 'bees')): 1.33333333333 (n = 12)
# ('9a', '4b', ('bus', 'passengers'), ('fast', 'slow')): 1.33333333333 (n = 12)
# ('3a', '4b', ('kid', 'child'), ('thin', 'fat')): 1.30769230769 (n = 13)
# ('4b', '2a', ('good', 'bad'), ('shoe', 'sole')): 1.30769230769 (n = 13)
# ('4b', '2a', ('excited', 'bored'), ('eye', 'lashes')): 1.30769230769 (n = 13)
# ('7c', '6a', ('chemist', 'beaker'), ('object', 'intangible')): 1.3 (n = 10)
# ('2a', '4b', ('cat', 'whiskers'), ('thin', 'fat')): 1.3 (n = 10)
# ('8a', '4b', ('sugar', 'energy'), ('thin', 'fat')): 1.3 (n = 10)
# ('4b', '3a', ('hairy', 'bald'), ('spectacles', 'glasses')): 1.3 (n = 10)
# ('2a', '4b', ('building', 'wall'), ('warm', 'cool')): 1.3 (n = 10)
# ('2a', '4b', ('book', 'spine'), ('easy', 'difficult')): 1.3 (n = 10)
# ('4b', '2a', ('dull', 'bright'), ('movie', 'scene')): 1.3 (n = 10)
# ('4b', '9a', ('bored', 'excited'), ('bus', 'passengers')): 1.3 (n = 10)
# ('4b', '10a', ('thin', 'fat'), ('valentine', 'love')): 1.3 (n = 10)
# ('6a', '7c', ('beauty', 'unpleasant'), ('pitcher', 'baseball')): 1.3 (n = 10)
# ('4b', '5a', ('bald', 'hairy'), ('blanket', 'soft')): 1.3 (n = 10)
# ('4b', '3a', ('good', 'bad'), ('sleep', 'doze')): 1.3 (n = 10)
# ('6a', '7c', ('enthusiasm', 'apathetic'), ('shopper', 'cart')): 1.3 (n = 10)
# ('10a', '4b', ('camera', 'distrust'), ('good', 'bad')): 1.27272727273 (n = 11)
# ('4b', '2a', ('black', 'white'), ('shoe', 'sole')): 1.27272727273 (n = 11)
# ('2a', '10a', ('bird', 'wings'), ('distrust', 'camera')): 1.27272727273 (n = 11)
# ('10a', '10a', ('camera', 'distrust'), ('thunder', 'lightning')): 1.25 (n = 12)
# ('2a', '4b', ('boat', 'motor'), ('bored', 'excited')): 1.25 (n = 12)
# ('4b', '3a', ('hot', 'cold'), ('run', 'sprint')): 1.25 (n = 12)
# ('2a', '4b', ('bunch', 'grape'), ('dull', 'bright')): 1.23076923077 (n = 13)
# ('5a', '6a', ('apple', 'red'), ('fire', 'cold')): 1.2 (n = 10)
# ('7c', '7d', ('fairy', 'wand'), ('forgive', 'sin')): 1.2 (n = 10)
# ('9a', '6a', ('airplane', 'hangar'), ('liar', 'honest')): 1.2 (n = 10)
# ('7c', '6a', ('maid', 'broom'), ('object', 'intangible')): 1.2 (n = 10)
# ('4b', '2a', ('dirty', 'clean'), ('eye', 'lashes')): 1.2 (n = 10)
# ('2a', '6a', ('computer', 'chip'), ('fire', 'cold')): 1.2 (n = 10)
# ('4b', '8a', ('bald', 'hairy'), ('heater', 'warmth')): 1.2 (n = 10)
# ('4b', '1a', ('ugly', 'pretty'), ('wheat', 'bread')): 1.2 (n = 10)
# ('4b', '7c', ('fat', 'thin'), ('hairdresser', 'comb')): 1.2 (n = 10)
# ('2a', '4b', ('computer', 'mouse'), ('easy', 'difficult')): 1.2 (n = 10)
# ('4b', '3a', ('bright', 'dark'), ('dress', 'frock')): 1.2 (n = 10)
# ('3a', '3a', ('flammable', 'inflammable'), ('spin', 'twirl')): 1.2 (n = 10)
# ('4b', '1a', ('excited', 'bored'), ('hair', 'brown')): 1.2 (n = 10)
# ('2a', '4b', ('bedroom', 'bed'), ('excited', 'bored')): 1.2 (n = 10)
# ('4b', '2a', ('bad', 'good'), ('freezer', 'ice')): 1.2 (n = 10)
# ('4b', '3a', ('chilly', 'warm'), ('music', 'tunes')): 1.16666666667 (n = 12)
# ('9a', '4b', ('bank', 'money'), ('fast', 'slow')): 1.1 (n = 10)
# ('4b', '8a', ('hot', 'cold'), ('injury', 'pain')): 1.1 (n = 10)
# ('4b', '1a', ('good', 'bad'), ('wheat', 'bread')): 1.08333333333 (n = 12)
# ('2a', '4b', ('bouquet', 'flower'), ('hot', 'cold')): 1.0 (n = 12)
# ('2a', '4b', ('bookcase', 'shelf'), ('pretty', 'ugly')): 1.0 (n = 12)
# ('3a', '4b', ('house', 'abode'), ('ugly', 'pretty')): 1.0 (n = 10)

# %%
# Save the mean ratings to a pickle file

import cPickle
ratings_pickle = 'relsim_mean_ratings.pickle'
with open(ratings_pickle, 'wb') as pickle_file:
    cPickle.dump(comp_ratings, pickle_file, cPickle.HIGHEST_PROTOCOL)
