# %%
import pandas as pd
import numpy as np

all_data = pd.read_csv('symmetry_raw_data.csv')
all_data[:11]
# Out:
#     sub_num  trial_num       trial_type relation1 relation2  pair1_word1  \
# 0         1          1  between-subtype        9h        9b    ingestion
# 1         1          2  between-subtype        4a        4g         rich
# 2         1          3  between-subtype        9d        9b      kitchen
# 3         1          4  between-subtype        6h        6g   discourage
# 4         1          5  between-subtype        5a        5b         fire
# 5         1          6   within-subtype        8a        8a     accident
# 6         1          7  between-subtype        2g        2a        house
# 7         1          8  between-subtype        9g        9e    adulthood
# 8         1          9     between-type        7c        9h      shooter
# 9         1         10   within-subtype        3e        3e    associate
# 10        1         11  attention check       NaN       NaN  coincidence
#
#    pair1_word2    pair2_word1  pair2_word2  rating     RT
# 0    digestion           mine         coal       1   7623
# 1         poor           hard       simple       1   7019
# 2          pot          dairy         milk       1   8010
# 3    confident          hurry       lazily       1  14199
# 4         heat       volatile  combustible       4   6833
# 5       damage         injury         pain       5   9784
# 6       bricks        bicycle        wheel       7   4386
# 7          job         margin        paper       1   4330
# 8          gun           step      journey       1   5117
# 9      partner          puppy          dog       1   4366
# 10         NaN  knowledgeable          NaN       1  10734

# %%
# Find the "bad" subjects--those who failed too many attention checks

fail_threshold = 2
bad_subs = []
attn_checks = all_data[all_data['trial_type'] == 'attention check']
for sub_num in attn_checks['sub_num'].unique():
    sub_data = attn_checks[attn_checks['sub_num'] == sub_num]
    same_words = sub_data['pair1_word1'] == sub_data['pair2_word1']
    diff_words = np.logical_not(same_words)
    not_rated_same = sub_data['rating'] != 7
    not_rated_diff = sub_data['rating'] != 1
    num_failed = np.sum(np.logical_or(np.logical_and(same_words, not_rated_same),
                                      np.logical_and(diff_words, not_rated_diff)))
    if num_failed >= fail_threshold:
        bad_subs.append(sub_num)
        
print 'Number of "bad" subjects:', len(bad_subs)
# Out:
# Number of "bad" subjects: 99

# %%
# Get the "good" data

good_rows = reduce(np.logical_and,
                   [all_data['sub_num'] != num for num in bad_subs])
good_data = all_data[good_rows]
print 'Number of "good" subjects:', len(good_data['sub_num'].unique())

real_trials = good_data[good_data['trial_type'] != 'attention check']

print 'Mean RT (seconds):', real_trials['RT'].mean() / 1000
print 'Mean overall rating:', real_trials['rating'].mean()
print
print 'Mean within-subtype rating:', real_trials[real_trials['trial_type'] == 'within-subtype']['rating'].mean()
print 'Mean between-subtype rating:', real_trials[real_trials['trial_type'] == 'between-subtype']['rating'].mean()
print 'Mean between-type rating:', real_trials[real_trials['trial_type'] == 'between-type']['rating'].mean()
# Out:
# Number of "good" subjects: 1003
# Mean RT (seconds): 10.6806863809
# Mean overall rating: 4.17122632104
#
# Mean within-subtype rating: 5.08619595758
# Mean between-subtype rating: 3.62911266201
# Mean between-type rating: 2.80408773679

# %%
# Create a dictionary of all individual ratings for each comparison. Each entry has
# the ratings for both the forward and backward directions.

def get_indiv_ratings_dict(data):
    ratings_dict = {}

    for r in xrange(data.shape[0]):
        row = data.iloc[r]
        rel1 = row['relation1']
        rel2 = row['relation2']
        pair1_word1 = row['pair1_word1']
        pair1_word2 = row['pair1_word2']
        pair2_word1 = row['pair2_word1']
        pair2_word2 = row['pair2_word2']
        rating = row['rating']

        comp = (rel1, rel2, (pair1_word1, pair1_word2), (pair2_word1, pair2_word2))
        rev_comp = (rel2, rel1, (pair2_word1, pair2_word2), (pair1_word1, pair1_word2))

        if comp in ratings_dict:
            ratings_dict[comp][0].append(rating)
        elif rev_comp in ratings_dict:
            ratings_dict[rev_comp][1].append(rating)
        else:
            ratings_dict[comp] = ([rating], [])
    
    return ratings_dict

all_indiv_ratings = get_indiv_ratings_dict(real_trials)

# %%
# Conduct a t-test for each comparison's forward and backward ratings

from scipy.stats import ttest_ind
import math

num_comps = len(all_indiv_ratings)

alpha = 0.05
num_sig = 0

print 'Comparisons with significantly different forward and backward relational similarity ratings:'
print

for comp, both_ratings in all_indiv_ratings.iteritems():
    fwd_ratings = both_ratings[0]
    bwd_ratings = both_ratings[1]
    
    mean1 = np.mean(fwd_ratings)
    SD1 = np.std(fwd_ratings, ddof=1)
    mean2 = np.mean(bwd_ratings)
    SD2 = np.std(bwd_ratings, ddof=1)
    
    _, prob = ttest_ind(fwd_ratings, bwd_ratings)
    
    if prob < alpha:
        num_sig += 1
        print comp
        print 'mean forward rating: {} (SD = {})'.format(mean1, SD1)
        print 'mean backward rating: {} (SD = {})'.format(mean2, SD2)
        print 't-test p-value:', prob
        print
# Out:
# Comparisons with significantly different forward and backward relational similarity ratings:
#
# ('7f', '6b', ('tip', 'waiter'), ('inexorable', 'halted'))
# mean forward rating: 1.84 (SD = 1.23486758771)
# mean backward rating: 2.54 (SD = 1.60623784042)
# t-test p-value: 0.0163536017794
#
# ('2a', '2b', ('fish', 'fin'), ('album', 'songs'))
# mean forward rating: 5.82352941176 (SD = 1.30699475673)
# mean backward rating: 4.84 (SD = 1.85560375784)
# t-test p-value: 0.00264295453185
#
# ('4h', '4h', ('pimple', 'skin'), ('leukemia', 'blood'))
# mean forward rating: 5.06 (SD = 1.91033707892)
# mean backward rating: 5.72 (SD = 1.10730413572)
# t-test p-value: 0.0370904825533
#
# ('9i', '9d', ('shirt', 'button'), ('garage', 'wrench'))
# mean forward rating: 3.74509803922 (SD = 2.14329780716)
# mean backward rating: 4.76 (SD = 1.59795788047)
# t-test p-value: 0.0083000846465
#
# ('8f', '5c', ('punch', 'pain'), ('ice', 'cold'))
# mean forward rating: 5.88 (SD = 1.25584348433)
# mean backward rating: 4.90196078431 (SD = 1.87888160309)
# t-test p-value: 0.00276830871357
#
# ('8f', '9c', ('automobile', 'transportation'), ('church', 'worship'))
# mean forward rating: 5.54 (SD = 1.75208330806)
# mean backward rating: 4.56 (SD = 2.10111729267)
# t-test p-value: 0.0128969286395
#
# ('10a', '10d', ('crossbones', 'poison'), ('outline', 'paper'))
# mean forward rating: 3.1 (SD = 1.85439356939)
# mean backward rating: 2.14 (SD = 1.45700279439)
# t-test p-value: 0.00490682119328
#
# ('3c', '3c', ('angry', 'enraged'), ('hot', 'burning'))
# mean forward rating: 6.12 (SD = 0.93982195448)
# mean backward rating: 5.44 (SD = 1.72804006)
# t-test p-value: 0.0162958770887
#
# ('2e', '2e', ('cooking', 'peeling'), ('knitting', 'purling'))
# mean forward rating: 5.29411764706 (SD = 1.51385755799)
# mean backward rating: 4.24 (SD = 1.82454914755)
# t-test p-value: 0.00207738412699
#
# ('10a', '10a', ('wrinkle', 'age'), ('cross', 'faith'))
# mean forward rating: 4.16 (SD = 2.23478985909)
# mean backward rating: 5.6 (SD = 1.39970842445)
# t-test p-value: 0.000202280232664
#
# ('9h', '9h', ('introduction', 'speech'), ('step', 'journey'))
# mean forward rating: 5.84 (SD = 1.53010603874)
# mean backward rating: 5.24 (SD = 1.42227182453)
# t-test p-value: 0.0449729360854
#
# ('2g', '2g', ('wine', 'alcohol'), ('atmosphere', 'gas'))
# mean forward rating: 4.46 (SD = 2.06239409128)
# mean backward rating: 5.42 (SD = 1.44405890546)
# t-test p-value: 0.00825602497973
#
# ('4c', '4c', ('abandon', 'embrace'), ('attract', 'repel'))
# mean forward rating: 6.3137254902 (SD = 1.27263814305)
# mean backward rating: 5.54 (SD = 1.82063007708)
# t-test p-value: 0.0148481656065
#
# ('5a', '5a', ('bigot', 'hateful'), ('pillow', 'soft'))
# mean forward rating: 5.08 (SD = 1.90423802319)
# mean backward rating: 5.84 (SD = 1.51670965028)
# t-test p-value: 0.0296130238537
#
# ('5e', '5e', ('sun', 'shine'), ('shovel', 'dig'))
# mean forward rating: 5.54 (SD = 1.44575381087)
# mean backward rating: 4.34 (SD = 2.13436412172)
# t-test p-value: 0.00138615331764
#
# ('8b', '8f', ('sadness', 'cry'), ('food', 'nourishment'))
# mean forward rating: 4.52 (SD = 1.79841199793)
# mean backward rating: 3.62 (SD = 1.90477380949)
# t-test p-value: 0.0169476652787
#
# ('10f', '10e', ('curtain', 'window'), ('anthropology', 'people'))
# mean forward rating: 3.16 (SD = 1.81107702763)
# mean backward rating: 2.38 (SD = 1.66463822141)
# t-test p-value: 0.0272057173535
#
# ('6g', '6d', ('stare', 'intermittently'), ('full', 'empty'))
# mean forward rating: 2.92 (SD = 1.72425671653)
# mean backward rating: 2.02 (SD = 1.30133369577)
# t-test p-value: 0.00402214389964
#
# ('8f', '8f', ('punch', 'pain'), ('food', 'nourishment'))
# mean forward rating: 5.82 (SD = 1.35058566283)
# mean backward rating: 4.82 (SD = 1.69861888676)
# t-test p-value: 0.00154048757075
#
# ('2c', '2h', ('quarter', 'pennies'), ('words', 'letters'))
# mean forward rating: 5.5 (SD = 1.46036059288)
# mean backward rating: 4.64 (SD = 1.89262801848)
# t-test p-value: 0.0125275291093
#
# ('3a', '3c', ('house', 'home'), ('hunger', 'starvation'))
# mean forward rating: 4.92 (SD = 2.06861878399)
# mean backward rating: 3.86 (SD = 2.21322555266)
# t-test p-value: 0.0150738551422
#
# ('9i', '9d', ('hands', 'gloves'), ('war', 'weapon'))
# mean forward rating: 3.26 (SD = 2.02847082245)
# mean backward rating: 4.08 (SD = 1.77096768198)
# t-test p-value: 0.0337508438513
#
# ('4a', '4h', ('cold', 'warm'), ('infertility', 'reproduction'))
# mean forward rating: 5.76 (SD = 1.69705627485)
# mean backward rating: 4.80392156863 (SD = 2.19106921701)
# t-test p-value: 0.0161119920022
#
# ('7e', '7e', ('pay', 'debtor'), ('preach', 'disciple'))
# mean forward rating: 4.92 (SD = 1.82767835334)
# mean backward rating: 3.92 (SD = 2.08825676739)
# t-test p-value: 0.0123868287802
#
# ('7f', '7f', ('donation', 'charity'), ('certificate', 'teacher'))
# mean forward rating: 4.18 (SD = 2.0572420611)
# mean backward rating: 3.29411764706 (SD = 2.06198077243)
# t-test p-value: 0.0330914039306
#
# ('8a', '2e', ('workout', 'sweat'), ('showering', 'soaping'))
# mean forward rating: 4.52 (SD = 1.92978797609)
# mean backward rating: 5.35294117647 (SD = 1.59779259495)
# t-test p-value: 0.019996460459
#
# ('1b', '1b', ('furniture', 'chair'), ('seat', 'chair'))
# mean forward rating: 4.88 (SD = 1.70999462942)
# mean backward rating: 4.08 (SD = 1.9149252663)
# t-test p-value: 0.0299068565394
#
# ('5h', '5i', ('repair', 'broken'), ('divide', 'parts'))
# mean forward rating: 3.2 (SD = 1.90595200916)
# mean backward rating: 2.32 (SD = 1.34680271422)
# t-test p-value: 0.00897213375006
#
# ('2f', '2f', ('tree', 'branch'), ('house', 'roof'))
# mean forward rating: 5.94117647059 (SD = 1.37712402791)
# mean backward rating: 5.08 (SD = 1.60152988083)
# t-test p-value: 0.00460508211327
#
# ('2c', '8d', ('book', 'chapters'), ('advertise', 'promote'))
# mean forward rating: 2.84 (SD = 2.08356053183)
# mean backward rating: 2.08 (SD = 1.36785248041)
# t-test p-value: 0.0335211961187
#
# ('8a', '8d', ('explosion', 'damage'), ('drink', 'hydrate'))
# mean forward rating: 5.42 (SD = 1.40102003657)
# mean backward rating: 4.68 (SD = 1.83436581935)
# t-test p-value: 0.0255897355912
#
# ('3h', '3h', ('rise', 'tide'), ('flood', 'water'))
# mean forward rating: 4.86 (SD = 1.76137701234)
# mean backward rating: 3.64705882353 (SD = 1.88492471374)
# t-test p-value: 0.00118278059198
#
# ('2e', '9f', ('therapy', 'talking'), ('spring', 'breeze'))
# mean forward rating: 3.38 (SD = 1.81703952986)
# mean backward rating: 4.21568627451 (SD = 2.08147760488)
# t-test p-value: 0.0341715685816
#
# ('9h', '1a', ('narrative', 'epilogue'), ('animal', 'pig'))
# mean forward rating: 2.8 (SD = 1.97948663722)
# mean backward rating: 3.84 (SD = 2.0737425499)
# t-test p-value: 0.0118289115575
#
# ('2a', '2b', ('bird', 'wings'), ('pack', 'wolf'))
# mean forward rating: 2.94 (SD = 1.86711607807)
# mean backward rating: 2.08 (SD = 1.58873585994)
# t-test p-value: 0.0148243350006
#
# ('5e', '5e', ('fire', 'burn'), ('baby', 'cry'))
# mean forward rating: 5.17647058824 (SD = 1.9152637662)
# mean backward rating: 5.86 (SD = 1.38519872589)
# t-test p-value: 0.0428426601855
#
# ('1b', '5e', ('clothing', 'shirt'), ('sun', 'shine'))
# mean forward rating: 2.14 (SD = 1.77292563468)
# mean backward rating: 3.06 (SD = 2.10354414244)
# t-test p-value: 0.0200150041805
#
# ('5d', '5c', ('emotional', 'turmoil'), ('psychotic', 'insanity'))
# mean forward rating: 5.14 (SD = 1.65381439128)
# mean backward rating: 4.1 (SD = 1.82107839771)
# t-test p-value: 0.00353346783015
#
# ('8h', '8h', ('sunscreen', 'burns'), ('water', 'thirst'))
# mean forward rating: 5.66 (SD = 1.5728564941)
# mean backward rating: 4.70588235294 (SD = 2.06198077243)
# t-test p-value: 0.0104352571166
#
# ('10e', '10e', ('mathematics', 'numbers'), ('anatomy', 'body'))
# mean forward rating: 6.3 (SD = 1.01519074311)
# mean backward rating: 5.84 (SD = 1.28349013973)
# t-test p-value: 0.049640339852
#
# ('9i', '9i', ('ear', 'earplug'), ('shirt', 'button'))
# mean forward rating: 4.5 (SD = 2.00254939555)
# mean backward rating: 3.74 (SD = 1.68801296058)
# t-test p-value: 0.0428494371512
#
# ('5d', '5d', ('happy', 'contentment'), ('angry', 'belligerence'))
# mean forward rating: 5.3137254902 (SD = 1.71452846087)
# mean backward rating: 6.1 (SD = 1.1823532398)
# t-test p-value: 0.00867404166923
#
# ('9c', '9f', ('store', 'shopping'), ('bedtime', 'sleeping'))
# mean forward rating: 4.36 (SD = 2.08747479516)
# mean backward rating: 5.68 (SD = 1.69561258571)
# t-test p-value: 0.000773643244573
#
# ('8h', '8h', ('knowledge', 'ignorance'), ('money', 'poverty'))
# mean forward rating: 5.76 (SD = 1.3932783246)
# mean backward rating: 6.47058823529 (SD = 1.11987394249)
# t-test p-value: 0.00567199818154
#
# ('3f', '3h', ('ladder', 'stairs'), ('goal', 'score'))
# mean forward rating: 4.48 (SD = 1.9716355999)
# mean backward rating: 3.4 (SD = 1.93780856661)
# t-test p-value: 0.00685197694621
#
# ('5a', '5b', ('water', 'wet'), ('dusty', 'dusted'))
# mean forward rating: 2.56862745098 (SD = 1.99253508838)
# mean backward rating: 3.88 (SD = 2.23734536577)
# t-test p-value: 0.00242747986359
#
# ('5a', '5a', ('diamond', 'shiny'), ('mogul', 'wealth'))
# mean forward rating: 4.74 (SD = 2.02847082245)
# mean backward rating: 3.84 (SD = 1.81107702763)
# t-test p-value: 0.0212968830152
#
# ('2j', '2e', ('husband', 'bachelorhood'), ('cooking', 'chopping'))
# mean forward rating: 2.60784313725 (SD = 1.86631649377)
# mean backward rating: 1.72549019608 (SD = 1.32783178713)
# t-test p-value: 0.00705267259521
#
# ('9f', '9b', ('winter', 'sledding'), ('refinery', 'oil'))
# mean forward rating: 3.36 (SD = 1.91407248279)
# mean backward rating: 2.42 (SD = 1.4155117341)
# t-test p-value: 0.00629773861559
#
# ('9d', '9a', ('sew', 'needle'), ('store', 'products'))
# mean forward rating: 4.0 (SD = 1.81827458019)
# mean backward rating: 2.3 (SD = 1.60674598274)
# t-test p-value: 3.03761200022e-06
#
# ('7c', '7c', ('hairdresser', 'comb'), ('pitcher', 'baseball'))
# mean forward rating: 6.1 (SD = 1.19948968741)
# mean backward rating: 4.84 (SD = 2.11274074827)
# t-test p-value: 0.000398542604119
#
# ('9d', '9e', ('church', 'pew'), ('edge', 'cliff'))
# mean forward rating: 3.58823529412 (SD = 1.95116857896)
# mean backward rating: 2.82352941176 (SD = 1.72865129338)
# t-test p-value: 0.0387014785526
#
# ('5i', '5c', ('stab', 'wound'), ('pacifist', 'peace'))
# mean forward rating: 4.18 (SD = 1.95552592227)
# mean backward rating: 3.18 (SD = 1.76923827723)
# t-test p-value: 0.00860416783533
#
# ('3h', '3h', ('dim', 'light'), ('darken', 'color'))
# mean forward rating: 4.1 (SD = 1.86536640817)
# mean backward rating: 5.38 (SD = 1.81703952986)
# t-test p-value: 0.000760816056836
#
# ('2i', '2g', ('bird', 'lips'), ('wall', 'bricks'))
# mean forward rating: 2.18 (SD = 1.91332598543)
# mean backward rating: 1.44 (SD = 0.812152594489)
# t-test p-value: 0.0134434761269
#
# ('2j', '2j', ('adult', 'childhood'), ('miscarriage', 'fetus'))
# mean forward rating: 2.62745098039 (SD = 1.9283234616)
# mean backward rating: 1.94 (SD = 1.42011784507)
# t-test p-value: 0.0443419983261
#
# ('8f', '8d', ('glue', 'adhesion'), ('shoot', 'kill'))
# mean forward rating: 4.6 (SD = 1.70233932683)
# mean backward rating: 5.4 (SD = 1.61624407128)
# t-test p-value: 0.0178249445133
#
# ('7f', '7e', ('check', 'employee'), ('lecture', 'child'))
# mean forward rating: 3.86 (SD = 1.80712874077)
# mean backward rating: 3.02 (SD = 1.97422162393)
# t-test p-value: 0.02877522783
#
# ('2c', '2c', ('quarter', 'pennies'), ('poem', 'verses'))
# mean forward rating: 4.8 (SD = 1.77281052086)
# mean backward rating: 3.88 (SD = 1.59897926624)
# t-test p-value: 0.00761839375119
#
# ('8f', '8f', ('hug', 'comfort'), ('medicine', 'recovery'))
# mean forward rating: 6.04 (SD = 1.15987332172)
# mean backward rating: 5.54 (SD = 1.12866184086)
# t-test p-value: 0.0313025552364
#
# ('9f', '9f', ('winter', 'snow'), ('winter', 'cold'))
# mean forward rating: 5.42 (SD = 1.485851642)
# mean backward rating: 4.64705882353 (SD = 1.85281979061)
# t-test p-value: 0.0229593593418
#
# ('7f', '7e', ('award', 'winner'), ('pay', 'debtor'))
# mean forward rating: 3.88 (SD = 2.27353900161)
# mean backward rating: 4.9 (SD = 1.82107839771)
# t-test p-value: 0.0150008043732
#
# ('6h', '6h', ('teach', 'ignorant'), ('groom', 'unkempt'))
# mean forward rating: 5.82 (SD = 1.62493327963)
# mean backward rating: 5.07843137255 (SD = 1.87449339561)
# t-test p-value: 0.0362763974431
#
# ('2d', '2f', ('circus', 'clown'), ('house', 'roof'))
# mean forward rating: 4.82 (SD = 1.99683422917)
# mean backward rating: 3.98 (SD = 1.94296218203)
# t-test p-value: 0.03551603109
#
# ('9d', '9d', ('kitchen', 'oven'), ('laboratory', 'reagents'))
# mean forward rating: 5.14 (SD = 1.52543068525)
# mean backward rating: 4.29411764706 (SD = 1.90046433955)
# t-test p-value: 0.015469570385
#
# ('2a', '2d', ('house', 'room'), ('restaurant', 'chef'))
# mean forward rating: 4.72 (SD = 1.86306747279)
# mean backward rating: 3.7 (SD = 2.17827866885)
# t-test p-value: 0.0134844359269
#
# ('5g', '5i', ('withdrawal', 'timid'), ('eat', 'satisfaction'))
# mean forward rating: 3.36 (SD = 1.89262801848)
# mean backward rating: 2.42 (SD = 1.70341793259)
# t-test p-value: 0.0104634069908
#
# ('8b', '8c', ('coldness', 'shiver'), ('battery', 'flashlight'))
# mean forward rating: 2.0 (SD = 1.35526185436)
# mean backward rating: 2.88 (SD = 1.85868068198)
# t-test p-value: 0.00805374140067
#
# ('7e', '7e', ('instruct', 'subordinate'), ('inspire', 'follower'))
# mean forward rating: 5.96 (SD = 1.51131784634)
# mean backward rating: 5.24 (SD = 1.73275762286)
# t-test p-value: 0.0291273536902
#
# ('6f', '6f', ('angry', 'smile'), ('exhausted', 'run'))
# mean forward rating: 4.76 (SD = 2.15292871243)
# mean backward rating: 2.36 (SD = 2.00774012466)
# t-test p-value: 9.49412653082e-08
#
# ('10f', '10f', ('password', 'access'), ('burka', 'body'))
# mean forward rating: 2.0 (SD = 1.41421356237)
# mean backward rating: 3.34 (SD = 1.84733674819)
# t-test p-value: 9.43244331148e-05
#
# ('2h', '2h', ('mother', 'children'), ('words', 'letters'))
# mean forward rating: 5.25490196078 (SD = 1.76457515856)
# mean backward rating: 3.82 (SD = 2.29186671978)
# t-test p-value: 0.000632940434624
#
# ('1b', '1b', ('garment', 'skirt'), ('artwork', 'sculpture'))
# mean forward rating: 6.54 (SD = 0.862128358264)
# mean backward rating: 6.0 (SD = 0.968904283304)
# t-test p-value: 0.00404403868983
#
# ('4h', '4h', ('deafness', 'hearing'), ('gap', 'teeth'))
# mean forward rating: 2.54 (SD = 1.98165051801)
# mean backward rating: 3.62 (SD = 1.8393654629)
# t-test p-value: 0.00573735356005
#
# ('7c', '9h', ('shooter', 'gun'), ('step', 'journey'))
# mean forward rating: 3.16 (SD = 1.98319470161)
# mean backward rating: 2.14 (SD = 1.38519872589)
# t-test p-value: 0.00361810166607

# %%
# Conduct a bionmial test to see if the number of significant t-tests is
# more than expected under the null hypothesis that presentation order
# doesn't matter

from scipy.stats import binom_test
p = binom_test(num_sig, num_comps, 0.05)
print 'Binomial test p-value:', p
# Out:
# Binomial test p-value: 3.9249911628e-17
